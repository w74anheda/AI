# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import tensorflow_datasets as tfds
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from imblearn.over_sampling import RandomOverSampler
import random
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.ensemble import IsolationForest

# %%
n = 10000
skip = sorted(random.sample(range(1,319795),319795-n))
DF = pd.read_csv('../../datasets/heart_2020_cleaned.csv',skiprows=skip).reset_index().rename(columns={'index':'id'})

# %%
# DF = pd.read_csv('../../datasets/heart_2020_cleaned.csv').reset_index().rename(columns={'index':'id'})
CatCols = [
    'Smoking','AlcoholDrinking','Stroke','DiffWalking','Sex','AgeCategory','Race','Diabetic',
    'PhysicalActivity','GenHealth','Asthma','KidneyDisease','SkinCancer'
]
NumCols = [
    'BMI', 'PhysicalHealth', 'MentalHealth', 'SleepTime'
]

X = DF[DF.columns.difference(['id','HeartDisease'])]
Y = DF['HeartDisease']

# %%
X.head()
# Out:
#    AgeCategory AlcoholDrinking Asthma    BMI Diabetic DiffWalking  GenHealth  \
# 0        55-59              No    Yes  16.60      Yes          No  Very good
# 1  80 or older              No     No  20.34       No          No  Very good
# 2        65-69              No    Yes  26.58      Yes          No       Fair
# 3        75-79              No     No  24.21       No          No       Good
# 4        40-44              No     No  23.71       No         Yes  Very good
#
#   KidneyDisease  MentalHealth PhysicalActivity  PhysicalHealth   Race     Sex  \
# 0            No          30.0              Yes             3.0  White  Female
# 1            No           0.0              Yes             0.0  White  Female
# 2            No          30.0              Yes            20.0  White    Male
# 3            No           0.0               No             0.0  White  Female
# 4            No           0.0              Yes            28.0  White  Female
#
#   SkinCancer  SleepTime Smoking Stroke
# 0        Yes        5.0     Yes     No
# 1         No        7.0      No    Yes
# 2         No        8.0     Yes     No
# 3        Yes        6.0      No     No
# 4         No        8.0      No     No

# %%
def columns_OHC_transforme(DF,columns):
    merged = pd.DataFrame()
    for column_name in columns:
        label_encoder = LabelEncoder()
        encoded = label_encoder.fit_transform(DF[column_name])
        labels =pd.Series(label_encoder.classes_)

        clmt = ColumnTransformer([(column_name,OneHotEncoder(),[0])], remainder='passthrough')
        clmt_fited_data = clmt.fit_transform(DF[[column_name]]) 
        clmt_fited_data = clmt_fited_data if type(clmt_fited_data)== np.ndarray else clmt_fited_data.toarray()
        NDF = pd.DataFrame(clmt_fited_data,columns=[f'{column_name}_{x}' for x in labels]).set_index(DF.index)
        merged = pd.concat([merged,NDF],axis=1)
    DF = DF.drop(columns=columns)
    DF = DF.merge(merged, left_index=True,right_index=True)

    return DF

# %%
X = columns_OHC_transforme(X,CatCols) 
Y_label_encoder = LabelEncoder()
Y = DF.iloc[X.index]['HeartDisease']
Y = Y_label_encoder.fit_transform(Y)

# %%
ss = StandardScaler()
X[NumCols] = ss.fit_transform(X[NumCols])

# %%
isoforest = IsolationForest(n_estimators=3000,max_features=50)
X['is_noise'] = isoforest.fit_predict(X)
X = X[X['is_noise'] == 1]
Y = Y[X.index]
X = X[X.columns.difference(['is_noise'])]

# %%
toml =RandomOverSampler(random_state=3020)
X, Y = toml.fit_resample(X,pd.DataFrame(Y,columns=['HeartDisease']))
# DF = pd.concat([X,pd.DataFrame(Y,columns=['HeartDisease'])],axis=1)

# %%
Y = pd.get_dummies(Y['HeartDisease'])

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,random_state=3020,train_size=.90)

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Dense(50,activation='relu',input_shape=(50,)),
    tf.keras.layers.Dense(100,activation='relu'),
#     tf.keras.layers.Dense(100,activation='relu'),
#     tf.keras.layers.Dense(100,activation='relu'),
#     tf.keras.layers.Dense(200,activation='relu'),
    tf.keras.layers.Dense(2,activation='softmax')
])

model.compile(
    optimizer=tf.keras.optimizers.Nadam(0.01),
    loss=tf.keras.losses.CategoricalCrossentropy(from_logits=True),
    metrics=[tf.keras.metrics.CategoricalAccuracy()]
)

# %%
model.fit(X_train, Y_train, epochs=200, validation_data=(X_test,Y_test), batch_size=60000)
# Out:
# Epoch 1/200
# /opt/conda/lib/python3.9/site-packages/keras/backend.py:5531: UserWarning: "`categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a Softmax activation and thus does not represent logits. Was this intended?
#   output, from_logits = _get_logits(
# 8/8 [==============================] - ETA: 0s - loss: 0.6458 - categorical_accuracy: 0.6417
# /opt/conda/lib/python3.9/site-packages/keras/backend.py:5531: UserWarning: "`categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a Softmax activation and thus does not represent logits. Was this intended?
#   output, from_logits = _get_logits(
# 8/8 [==============================] - 4s 339ms/step - loss: 0.6458 - categorical_accuracy: 0.6417 - val_loss: 0.6138 - val_categorical_accuracy: 0.6818
# Epoch 2/200
# 8/8 [==============================] - 2s 303ms/step - loss: 0.6021 - categorical_accuracy: 0.7030 - val_loss: 0.5260 - val_categorical_accuracy: 0.7476
# Epoch 3/200
# 8/8 [==============================] - 2s 303ms/step - loss: 0.5175 - categorical_accuracy: 0.7519 - val_loss: 0.5192 - val_categorical_accuracy: 0.7467
# Epoch 4/200
# 8/8 [==============================] - 3s 328ms/step - loss: 0.5188 - categorical_accuracy: 0.7492 - val_loss: 0.5167 - val_categorical_accuracy: 0.7479
# Epoch 5/200
# 8/8 [==============================] - 2s 306ms/step - loss: 0.5100 - categorical_accuracy: 0.7555 - val_loss: 0.5104 - val_categorical_accuracy: 0.7527
# Epoch 6/200
# 8/8 [==============================] - 2s 311ms/step - loss: 0.5121 - categorical_accuracy: 0.7534 - val_loss: 0.5237 - val_categorical_accuracy: 0.7413
# Epoch 7/200
# 8/8 [==============================] - 3s 334ms/step - loss: 0.5102 - categorical_accuracy: 0.7544 - val_loss: 0.5073 - val_categorical_accuracy: 0.7551
# Epoch 8/200
# 8/8 [==============================] - 2s 322ms/step - loss: 0.5046 - categorical_accuracy: 0.7585 - val_loss: 0.5097 - val_categorical_accuracy: 0.7533
# Epoch 9/200
# 8/8 [==============================] - 3s 322ms/step - loss: 0.5127 - categorical_accuracy: 0.7525 - val_loss: 0.5096 - val_categorical_accuracy: 0.7531
# Epoch 10/200
# 8/8 [==============================] - 3s 322ms/step - loss: 0.5047 - categorical_accuracy: 0.7579 - val_loss: 0.5078 - val_categorical_accuracy: 0.7546
# Epoch 11/200
# 8/8 [==============================] - 2s 311ms/step - loss: 0.5066 - categorical_accuracy: 0.7565 - val_loss: 0.5087 - val_categorical_accuracy: 0.7531
# Epoch 12/200
# 8/8 [==============================] - 2s 316ms/step - loss: 0.5039 - categorical_accuracy: 0.7581 - val_loss: 0.5078 - val_categorical_accuracy: 0.7542
# Epoch 13/200
# 8/8 [==============================] - 2s 319ms/step - loss: 0.5062 - categorical_accuracy: 0.7564 - val_loss: 0.5079 - val_categorical_accuracy: 0.7543
# Epoch 14/200
# 8/8 [==============================] - 3s 362ms/step - loss: 0.5024 - categorical_accuracy: 0.7592 - val_loss: 0.5056 - val_categorical_accuracy: 0.7564
# Epoch 15/200
# 8/8 [==============================] - 3s 365ms/step - loss: 0.5034 - categorical_accuracy: 0.7582 - val_loss: 0.5071 - val_categorical_accuracy: 0.7554
# Epoch 16/200
# 8/8 [==============================] - 3s 377ms/step - loss: 0.5026 - categorical_accuracy: 0.7585 - val_loss: 0.5026 - val_categorical_accuracy: 0.7587
# Epoch 17/200
# 8/8 [==============================] - 3s 356ms/step - loss: 0.4998 - categorical_accuracy: 0.7606 - val_loss: 0.5070 - val_categorical_accuracy: 0.7549
# Epoch 18/200
# 8/8 [==============================] - 3s 353ms/step - loss: 0.5024 - categorical_accuracy: 0.7583 - val_loss: 0.5010 - val_categorical_accuracy: 0.7590
# Epoch 19/200
# 8/8 [==============================] - 3s 376ms/step - loss: 0.4983 - categorical_accuracy: 0.7615 - val_loss: 0.5012 - val_categorical_accuracy: 0.7588
# Epoch 20/200
# 8/8 [==============================] - 3s 383ms/step - loss: 0.5006 - categorical_accuracy: 0.7597 - val_loss: 0.5015 - val_categorical_accuracy: 0.7586
# Epoch 21/200
# 8/8 [==============================] - 3s 361ms/step - loss: 0.4982 - categorical_accuracy: 0.7613 - val_loss: 0.5020 - val_categorical_accuracy: 0.7585
# Epoch 22/200
# 8/8 [==============================] - 3s 360ms/step - loss: 0.4983 - categorical_accuracy: 0.7612 - val_loss: 0.4988 - val_categorical_accuracy: 0.7599
# Epoch 23/200
# 8/8 [==============================] - 3s 357ms/step - loss: 0.4974 - categorical_accuracy: 0.7621 - val_loss: 0.5034 - val_categorical_accuracy: 0.7569
# Epoch 24/200
# 8/8 [==============================] - 3s 368ms/step - loss: 0.4970 - categorical_accuracy: 0.7626 - val_loss: 0.5012 - val_categorical_accuracy: 0.7587
# Epoch 25/200
# 8/8 [==============================] - 3s 387ms/step - loss: 0.4964 - categorical_accuracy: 0.7623 - val_loss: 0.4979 - val_categorical_accuracy: 0.7600
# Epoch 26/200
# 8/8 [==============================] - 3s 389ms/step - loss: 0.4943 - categorical_accuracy: 0.7638 - val_loss: 0.4974 - val_categorical_accuracy: 0.7606
# Epoch 27/200
# 8/8 [==============================] - 3s 374ms/step - loss: 0.4962 - categorical_accuracy: 0.7626 - val_loss: 0.4979 - val_categorical_accuracy: 0.7602
# Epoch 28/200
# 8/8 [==============================] - 3s 356ms/step - loss: 0.4933 - categorical_accuracy: 0.7650 - val_loss: 0.4943 - val_categorical_accuracy: 0.7623
# Epoch 29/200
# 8/8 [==============================] - 3s 379ms/step - loss: 0.4903 - categorical_accuracy: 0.7658 - val_loss: 0.5027 - val_categorical_accuracy: 0.7582
# Epoch 30/200
# 8/8 [==============================] - 3s 380ms/step - loss: 0.4934 - categorical_accuracy: 0.7648 - val_loss: 0.4950 - val_categorical_accuracy: 0.7615
# Epoch 31/200
# 8/8 [==============================] - 3s 389ms/step - loss: 0.4910 - categorical_accuracy: 0.7659 - val_loss: 0.4949 - val_categorical_accuracy: 0.7621
# Epoch 32/200
# 8/8 [==============================] - 3s 367ms/step - loss: 0.4903 - categorical_accuracy: 0.7661 - val_loss: 0.4981 - val_categorical_accuracy: 0.7599
# Epoch 33/200
# 8/8 [==============================] - 3s 383ms/step - loss: 0.4914 - categorical_accuracy: 0.7653 - val_loss: 0.4928 - val_categorical_accuracy: 0.7628
# Epoch 34/200
# 8/8 [==============================] - 3s 359ms/step - loss: 0.4883 - categorical_accuracy: 0.7677 - val_loss: 0.4910 - val_categorical_accuracy: 0.7640
# Epoch 35/200
# 8/8 [==============================] - 3s 370ms/step - loss: 0.4876 - categorical_accuracy: 0.7677 - val_loss: 0.4892 - val_categorical_accuracy: 0.7652
# Epoch 36/200
# 8/8 [==============================] - 3s 356ms/step - loss: 0.4884 - categorical_accuracy: 0.7675 - val_loss: 0.4937 - val_categorical_accuracy: 0.7630
# Epoch 37/200
# 8/8 [==============================] - 3s 370ms/step - loss: 0.4866 - categorical_accuracy: 0.7683 - val_loss: 0.4889 - val_categorical_accuracy: 0.7664
# Epoch 38/200
# 8/8 [==============================] - 3s 364ms/step - loss: 0.4838 - categorical_accuracy: 0.7701 - val_loss: 0.4919 - val_categorical_accuracy: 0.7640
# Epoch 39/200
# 8/8 [==============================] - 3s 379ms/step - loss: 0.4873 - categorical_accuracy: 0.7682 - val_loss: 0.4920 - val_categorical_accuracy: 0.7641
# Epoch 40/200
# 8/8 [==============================] - 3s 375ms/step - loss: 0.4851 - categorical_accuracy: 0.7690 - val_loss: 0.4865 - val_categorical_accuracy: 0.7673
# Epoch 41/200
# 8/8 [==============================] - 3s 361ms/step - loss: 0.4832 - categorical_accuracy: 0.7702 - val_loss: 0.4891 - val_categorical_accuracy: 0.7659
# Epoch 42/200
# 8/8 [==============================] - 3s 352ms/step - loss: 0.4835 - categorical_accuracy: 0.7701 - val_loss: 0.4855 - val_categorical_accuracy: 0.7674
# Epoch 43/200
# 8/8 [==============================] - 3s 365ms/step - loss: 0.4838 - categorical_accuracy: 0.7696 - val_loss: 0.4900 - val_categorical_accuracy: 0.7652
# Epoch 44/200
# 8/8 [==============================] - 3s 368ms/step - loss: 0.4802 - categorical_accuracy: 0.7727 - val_loss: 0.4850 - val_categorical_accuracy: 0.7679
# Epoch 45/200
# 8/8 [==============================] - 3s 374ms/step - loss: 0.4799 - categorical_accuracy: 0.7724 - val_loss: 0.4868 - val_categorical_accuracy: 0.7665
# Epoch 46/200
# 8/8 [==============================] - 3s 384ms/step - loss: 0.4799 - categorical_accuracy: 0.7725 - val_loss: 0.4847 - val_categorical_accuracy: 0.7684
# Epoch 47/200
# 8/8 [==============================] - 3s 361ms/step - loss: 0.4801 - categorical_accuracy: 0.7725 - val_loss: 0.4832 - val_categorical_accuracy: 0.7699
# Epoch 48/200
# 8/8 [==============================] - 3s 371ms/step - loss: 0.4755 - categorical_accuracy: 0.7752 - val_loss: 0.4848 - val_categorical_accuracy: 0.7685
# Epoch 49/200
# 8/8 [==============================] - 3s 344ms/step - loss: 0.4818 - categorical_accuracy: 0.7717 - val_loss: 0.4808 - val_categorical_accuracy: 0.7719
# Epoch 50/200
# 8/8 [==============================] - 3s 368ms/step - loss: 0.4763 - categorical_accuracy: 0.7745 - val_loss: 0.4830 - val_categorical_accuracy: 0.7698
# Epoch 51/200
# 8/8 [==============================] - 3s 372ms/step - loss: 0.4770 - categorical_accuracy: 0.7740 - val_loss: 0.4804 - val_categorical_accuracy: 0.7720
# Epoch 52/200
# 8/8 [==============================] - 3s 361ms/step - loss: 0.4755 - categorical_accuracy: 0.7748 - val_loss: 0.4796 - val_categorical_accuracy: 0.7720
# Epoch 53/200
# 8/8 [==============================] - 3s 372ms/step - loss: 0.4748 - categorical_accuracy: 0.7754 - val_loss: 0.4800 - val_categorical_accuracy: 0.7715
# Epoch 54/200
# 8/8 [==============================] - 3s 362ms/step - loss: 0.4760 - categorical_accuracy: 0.7743 - val_loss: 0.4813 - val_categorical_accuracy: 0.7703
# Epoch 55/200
# 8/8 [==============================] - 3s 370ms/step - loss: 0.4733 - categorical_accuracy: 0.7761 - val_loss: 0.4802 - val_categorical_accuracy: 0.7706
# Epoch 56/200
# 8/8 [==============================] - 3s 362ms/step - loss: 0.4755 - categorical_accuracy: 0.7748 - val_loss: 0.4800 - val_categorical_accuracy: 0.7713
# Epoch 57/200
# 8/8 [==============================] - 3s 339ms/step - loss: 0.4732 - categorical_accuracy: 0.7760 - val_loss: 0.4791 - val_categorical_accuracy: 0.7717
# Epoch 58/200
# 8/8 [==============================] - 3s 347ms/step - loss: 0.4717 - categorical_accuracy: 0.7767 - val_loss: 0.4813 - val_categorical_accuracy: 0.7701
# Epoch 59/200
# 8/8 [==============================] - 3s 369ms/step - loss: 0.4718 - categorical_accuracy: 0.7770 - val_loss: 0.4803 - val_categorical_accuracy: 0.7700
# Epoch 60/200
# 8/8 [==============================] - 3s 373ms/step - loss: 0.4691 - categorical_accuracy: 0.7783 - val_loss: 0.4772 - val_categorical_accuracy: 0.7728
# Epoch 61/200
# 8/8 [==============================] - 3s 371ms/step - loss: 0.4732 - categorical_accuracy: 0.7760 - val_loss: 0.4776 - val_categorical_accuracy: 0.7727
# Epoch 62/200
# 8/8 [==============================] - 3s 374ms/step - loss: 0.4701 - categorical_accuracy: 0.7779 - val_loss: 0.4757 - val_categorical_accuracy: 0.7727
# Epoch 63/200
# 8/8 [==============================] - 3s 393ms/step - loss: 0.4706 - categorical_accuracy: 0.7763 - val_loss: 0.4770 - val_categorical_accuracy: 0.7726
# Epoch 64/200
# 8/8 [==============================] - 3s 358ms/step - loss: 0.4673 - categorical_accuracy: 0.7794 - val_loss: 0.4738 - val_categorical_accuracy: 0.7740
# Epoch 65/200
# 8/8 [==============================] - 3s 346ms/step - loss: 0.4685 - categorical_accuracy: 0.7785 - val_loss: 0.4748 - val_categorical_accuracy: 0.7735
# Epoch 66/200
# 8/8 [==============================] - 3s 364ms/step - loss: 0.4680 - categorical_accuracy: 0.7781 - val_loss: 0.4810 - val_categorical_accuracy: 0.7699
# Epoch 67/200
# 8/8 [==============================] - 3s 379ms/step - loss: 0.4692 - categorical_accuracy: 0.7782 - val_loss: 0.4717 - val_categorical_accuracy: 0.7761
# Epoch 68/200
# 8/8 [==============================] - 3s 379ms/step - loss: 0.4641 - categorical_accuracy: 0.7808 - val_loss: 0.4714 - val_categorical_accuracy: 0.7752
# Epoch 69/200
# 8/8 [==============================] - 3s 358ms/step - loss: 0.4688 - categorical_accuracy: 0.7783 - val_loss: 0.4770 - val_categorical_accuracy: 0.7722
# Epoch 70/200
# 8/8 [==============================] - 3s 367ms/step - loss: 0.4645 - categorical_accuracy: 0.7810 - val_loss: 0.4726 - val_categorical_accuracy: 0.7737
# Epoch 71/200
# 8/8 [==============================] - 3s 385ms/step - loss: 0.4649 - categorical_accuracy: 0.7802 - val_loss: 0.4746 - val_categorical_accuracy: 0.7730
# Epoch 72/200
# 8/8 [==============================] - 3s 365ms/step - loss: 0.4658 - categorical_accuracy: 0.7803 - val_loss: 0.4709 - val_categorical_accuracy: 0.7761
# Epoch 73/200
# 8/8 [==============================] - 3s 369ms/step - loss: 0.4599 - categorical_accuracy: 0.7837 - val_loss: 0.4715 - val_categorical_accuracy: 0.7758
# Epoch 74/200
# 8/8 [==============================] - 3s 366ms/step - loss: 0.4650 - categorical_accuracy: 0.7809 - val_loss: 0.4755 - val_categorical_accuracy: 0.7720
# Epoch 75/200
# 8/8 [==============================] - 3s 375ms/step - loss: 0.4644 - categorical_accuracy: 0.7810 - val_loss: 0.4738 - val_categorical_accuracy: 0.7751
# Epoch 76/200
# 8/8 [==============================] - 3s 353ms/step - loss: 0.4640 - categorical_accuracy: 0.7811 - val_loss: 0.4676 - val_categorical_accuracy: 0.7794
# Epoch 77/200
# 8/8 [==============================] - 3s 373ms/step - loss: 0.4587 - categorical_accuracy: 0.7843 - val_loss: 0.4696 - val_categorical_accuracy: 0.7770
# Epoch 78/200
# 8/8 [==============================] - 3s 366ms/step - loss: 0.4641 - categorical_accuracy: 0.7809 - val_loss: 0.4721 - val_categorical_accuracy: 0.7747
# Epoch 79/200
# 8/8 [==============================] - 3s 359ms/step - loss: 0.4587 - categorical_accuracy: 0.7844 - val_loss: 0.4657 - val_categorical_accuracy: 0.7789
# Epoch 80/200
# 8/8 [==============================] - 3s 360ms/step - loss: 0.4613 - categorical_accuracy: 0.7826 - val_loss: 0.4712 - val_categorical_accuracy: 0.7753
# Epoch 81/200
# 8/8 [==============================] - 3s 373ms/step - loss: 0.4618 - categorical_accuracy: 0.7831 - val_loss: 0.4669 - val_categorical_accuracy: 0.7796
# Epoch 82/200
# 8/8 [==============================] - 3s 375ms/step - loss: 0.4586 - categorical_accuracy: 0.7847 - val_loss: 0.4718 - val_categorical_accuracy: 0.7742
# Epoch 83/200
# 8/8 [==============================] - 3s 372ms/step - loss: 0.4605 - categorical_accuracy: 0.7830 - val_loss: 0.4662 - val_categorical_accuracy: 0.7795
# Epoch 84/200
# 8/8 [==============================] - 3s 365ms/step - loss: 0.4562 - categorical_accuracy: 0.7860 - val_loss: 0.4642 - val_categorical_accuracy: 0.7802
# Epoch 85/200
# 8/8 [==============================] - 3s 367ms/step - loss: 0.4572 - categorical_accuracy: 0.7852 - val_loss: 0.4724 - val_categorical_accuracy: 0.7759
# Epoch 86/200
# 8/8 [==============================] - 3s 380ms/step - loss: 0.4605 - categorical_accuracy: 0.7829 - val_loss: 0.4650 - val_categorical_accuracy: 0.7795
# Epoch 87/200
# 8/8 [==============================] - 3s 394ms/step - loss: 0.4562 - categorical_accuracy: 0.7860 - val_loss: 0.4716 - val_categorical_accuracy: 0.7760
# Epoch 88/200
# 8/8 [==============================] - 3s 382ms/step - loss: 0.4597 - categorical_accuracy: 0.7832 - val_loss: 0.4650 - val_categorical_accuracy: 0.7797
# Epoch 89/200
# 8/8 [==============================] - 3s 356ms/step - loss: 0.4539 - categorical_accuracy: 0.7873 - val_loss: 0.4665 - val_categorical_accuracy: 0.7786
# Epoch 90/200
# 8/8 [==============================] - 3s 359ms/step - loss: 0.4605 - categorical_accuracy: 0.7828 - val_loss: 0.4646 - val_categorical_accuracy: 0.7794
# Epoch 91/200
# 8/8 [==============================] - 3s 373ms/step - loss: 0.4547 - categorical_accuracy: 0.7865 - val_loss: 0.4642 - val_categorical_accuracy: 0.7809
# Epoch 92/200
# 8/8 [==============================] - 3s 387ms/step - loss: 0.4562 - categorical_accuracy: 0.7852 - val_loss: 0.4642 - val_categorical_accuracy: 0.7803
# Epoch 93/200
# 8/8 [==============================] - 3s 373ms/step - loss: 0.4528 - categorical_accuracy: 0.7876 - val_loss: 0.4651 - val_categorical_accuracy: 0.7800
# Epoch 94/200
# 8/8 [==============================] - 3s 392ms/step - loss: 0.4556 - categorical_accuracy: 0.7861 - val_loss: 0.4628 - val_categorical_accuracy: 0.7803
# Epoch 95/200
# 8/8 [==============================] - 3s 365ms/step - loss: 0.4549 - categorical_accuracy: 0.7862 - val_loss: 0.4616 - val_categorical_accuracy: 0.7803
# Epoch 96/200
# 8/8 [==============================] - 3s 381ms/step - loss: 0.4549 - categorical_accuracy: 0.7858 - val_loss: 0.4626 - val_categorical_accuracy: 0.7804
# Epoch 97/200
# 8/8 [==============================] - 3s 372ms/step - loss: 0.4531 - categorical_accuracy: 0.7873 - val_loss: 0.4616 - val_categorical_accuracy: 0.7808
# Epoch 98/200
# 8/8 [==============================] - 3s 379ms/step - loss: 0.4503 - categorical_accuracy: 0.7888 - val_loss: 0.4603 - val_categorical_accuracy: 0.7813
# Epoch 99/200
# 8/8 [==============================] - 3s 373ms/step - loss: 0.4514 - categorical_accuracy: 0.7884 - val_loss: 0.4671 - val_categorical_accuracy: 0.7772
# Epoch 100/200
# 8/8 [==============================] - 3s 368ms/step - loss: 0.4563 - categorical_accuracy: 0.7854 - val_loss: 0.4598 - val_categorical_accuracy: 0.7821
# Epoch 101/200
# 8/8 [==============================] - 3s 372ms/step - loss: 0.4500 - categorical_accuracy: 0.7892 - val_loss: 0.4600 - val_categorical_accuracy: 0.7816
# Epoch 102/200
# 8/8 [==============================] - 3s 360ms/step - loss: 0.4497 - categorical_accuracy: 0.7893 - val_loss: 0.4614 - val_categorical_accuracy: 0.7807
# Epoch 103/200
# 8/8 [==============================] - 3s 352ms/step - loss: 0.4508 - categorical_accuracy: 0.7883 - val_loss: 0.4590 - val_categorical_accuracy: 0.7820
# Epoch 104/200
# 8/8 [==============================] - 3s 347ms/step - loss: 0.4526 - categorical_accuracy: 0.7876 - val_loss: 0.4583 - val_categorical_accuracy: 0.7846
# Epoch 105/200
# 8/8 [==============================] - 3s 376ms/step - loss: 0.4460 - categorical_accuracy: 0.7913 - val_loss: 0.4557 - val_categorical_accuracy: 0.7854
# Epoch 106/200
# 8/8 [==============================] - 3s 372ms/step - loss: 0.4493 - categorical_accuracy: 0.7891 - val_loss: 0.4644 - val_categorical_accuracy: 0.7798
# Epoch 107/200
# 8/8 [==============================] - 3s 406ms/step - loss: 0.4499 - categorical_accuracy: 0.7894 - val_loss: 0.4593 - val_categorical_accuracy: 0.7818
# Epoch 108/200
# 8/8 [==============================] - 3s 412ms/step - loss: 0.4479 - categorical_accuracy: 0.7901 - val_loss: 0.4552 - val_categorical_accuracy: 0.7857
# Epoch 109/200
# 8/8 [==============================] - 3s 398ms/step - loss: 0.4450 - categorical_accuracy: 0.7918 - val_loss: 0.4557 - val_categorical_accuracy: 0.7865
# Epoch 110/200
# 8/8 [==============================] - 3s 383ms/step - loss: 0.4486 - categorical_accuracy: 0.7902 - val_loss: 0.4607 - val_categorical_accuracy: 0.7801
# Epoch 111/200
# 8/8 [==============================] - 3s 360ms/step - loss: 0.4483 - categorical_accuracy: 0.7897 - val_loss: 0.4594 - val_categorical_accuracy: 0.7831
# Epoch 112/200
# 8/8 [==============================] - 3s 361ms/step - loss: 0.4472 - categorical_accuracy: 0.7902 - val_loss: 0.4613 - val_categorical_accuracy: 0.7815
# Epoch 113/200
# 8/8 [==============================] - 3s 363ms/step - loss: 0.4487 - categorical_accuracy: 0.7899 - val_loss: 0.4553 - val_categorical_accuracy: 0.7863
# Epoch 114/200
# 8/8 [==============================] - 3s 361ms/step - loss: 0.4423 - categorical_accuracy: 0.7933 - val_loss: 0.4581 - val_categorical_accuracy: 0.7813
# Epoch 115/200
# 8/8 [==============================] - 3s 354ms/step - loss: 0.4502 - categorical_accuracy: 0.7885 - val_loss: 0.4582 - val_categorical_accuracy: 0.7832
# Epoch 116/200
# 8/8 [==============================] - 3s 368ms/step - loss: 0.4457 - categorical_accuracy: 0.7912 - val_loss: 0.4549 - val_categorical_accuracy: 0.7856
# Epoch 117/200
# 8/8 [==============================] - 3s 392ms/step - loss: 0.4449 - categorical_accuracy: 0.7919 - val_loss: 0.4563 - val_categorical_accuracy: 0.7840
# Epoch 118/200
# 8/8 [==============================] - 3s 352ms/step - loss: 0.4454 - categorical_accuracy: 0.7915 - val_loss: 0.4569 - val_categorical_accuracy: 0.7831
# Epoch 119/200
# 8/8 [==============================] - 3s 359ms/step - loss: 0.4455 - categorical_accuracy: 0.7913 - val_loss: 0.4544 - val_categorical_accuracy: 0.7859
# Epoch 120/200
# 8/8 [==============================] - 3s 337ms/step - loss: 0.4426 - categorical_accuracy: 0.7933 - val_loss: 0.4528 - val_categorical_accuracy: 0.7862
# Epoch 121/200
# 8/8 [==============================] - 3s 378ms/step - loss: 0.4440 - categorical_accuracy: 0.7921 - val_loss: 0.4572 - val_categorical_accuracy: 0.7821
# Epoch 122/200
# 8/8 [==============================] - 3s 392ms/step - loss: 0.4443 - categorical_accuracy: 0.7917 - val_loss: 0.4583 - val_categorical_accuracy: 0.7821
# Epoch 123/200
# 8/8 [==============================] - 3s 373ms/step - loss: 0.4445 - categorical_accuracy: 0.7925 - val_loss: 0.4554 - val_categorical_accuracy: 0.7843
# Epoch 124/200
# 8/8 [==============================] - 3s 368ms/step - loss: 0.4400 - categorical_accuracy: 0.7943 - val_loss: 0.4522 - val_categorical_accuracy: 0.7863
# Epoch 125/200
# 8/8 [==============================] - 3s 365ms/step - loss: 0.4441 - categorical_accuracy: 0.7925 - val_loss: 0.4558 - val_categorical_accuracy: 0.7830
# Epoch 126/200
# 8/8 [==============================] - 3s 401ms/step - loss: 0.4421 - categorical_accuracy: 0.7930 - val_loss: 0.4567 - val_categorical_accuracy: 0.7827
# Epoch 127/200
# 8/8 [==============================] - 3s 395ms/step - loss: 0.4416 - categorical_accuracy: 0.7940 - val_loss: 0.4507 - val_categorical_accuracy: 0.7878
# Epoch 128/200
# 8/8 [==============================] - 3s 392ms/step - loss: 0.4410 - categorical_accuracy: 0.7943 - val_loss: 0.4544 - val_categorical_accuracy: 0.7841
# Epoch 129/200
# 8/8 [==============================] - 3s 421ms/step - loss: 0.4419 - categorical_accuracy: 0.7936 - val_loss: 0.4501 - val_categorical_accuracy: 0.7875
# Epoch 130/200
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [163], line 1
# ----> 1 model.fit(X_train, Y_train, epochs=200, validation_data=(X_test,Y_test), batch_size=60000)
#
# File /opt/conda/lib/python3.9/site-packages/keras/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /opt/conda/lib/python3.9/site-packages/keras/engine/training.py:1564, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1556 with tf.profiler.experimental.Trace(
#    1557     "train",
#    1558     epoch_num=epoch,
#    (...)
#    1561     _r=1,
#    1562 ):
#    1563     callbacks.on_train_batch_begin(step)
# -> 1564     tmp_logs = self.train_function(iterator)
#    1565     if data_handler.should_sync:
#    1566         context.async_wait()
#
# File /opt/conda/lib/python3.9/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /opt/conda/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py:915, in Function.__call__(self, *args, **kwds)
#     912 compiler = "xla" if self._jit_compile else "nonXla"
#     914 with OptionalXlaContext(self._jit_compile):
# --> 915   result = self._call(*args, **kwds)
#     917 new_tracing_count = self.experimental_get_tracing_count()
#     918 without_tracing = (tracing_count == new_tracing_count)
#
# File /opt/conda/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py:947, in Function._call(self, *args, **kwds)
#     944   self._lock.release()
#     945   # In this case we have created variables on the first call, so we run the
#     946   # defunned version which is guaranteed to never create variables.
# --> 947   return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     948 elif self._stateful_fn is not None:
#     949   # Release the lock early so that multiple threads can perform the call
#     950   # in parallel.
#     951   self._lock.release()
#
# File /opt/conda/lib/python3.9/site-packages/tensorflow/python/eager/function.py:2496, in Function.__call__(self, *args, **kwargs)
#    2493 with self._lock:
#    2494   (graph_function,
#    2495    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2496 return graph_function._call_flat(
#    2497     filtered_flat_args, captured_inputs=graph_function.captured_inputs)
#
# File /opt/conda/lib/python3.9/site-packages/tensorflow/python/eager/function.py:1862, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1858 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1859 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1860     and executing_eagerly):
#    1861   # No tape is watching; skip to running the function.
# -> 1862   return self._build_call_outputs(self._inference_function.call(
#    1863       ctx, args, cancellation_manager=cancellation_manager))
#    1864 forward_backward = self._select_forward_and_backward_functions(
#    1865     args,
#    1866     possible_gradient_type,
#    1867     executing_eagerly)
#    1868 forward_function, args_with_tangents = forward_backward.forward()
#
# File /opt/conda/lib/python3.9/site-packages/tensorflow/python/eager/function.py:499, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     497 with _InterpolateFunctionError(self):
#     498   if cancellation_manager is None:
# --> 499     outputs = execute.execute(
#     500         str(self.signature.name),
#     501         num_outputs=self._num_outputs,
#     502         inputs=args,
#     503         attrs=attrs,
#     504         ctx=ctx)
#     505   else:
#     506     outputs = execute.execute_with_cancellation(
#     507         str(self.signature.name),
#     508         num_outputs=self._num_outputs,
#    (...)
#     511         ctx=ctx,
#     512         cancellation_manager=cancellation_manager)
#
# File /opt/conda/lib/python3.9/site-packages/tensorflow/python/eager/execute.py:54, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52 try:
#      53   ctx.ensure_initialized()
# ---> 54   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                       inputs, attrs, num_outputs)
#      56 except core._NotOkStatusException as e:
#      57   if name is not None:
#
# KeyboardInterrupt:

# %%
model.summary()
# Out:
# Model: "sequential_32"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_110 (Dense)           (None, 50)                2550
#
#  dense_111 (Dense)           (None, 100)               5100
#
#  dense_112 (Dense)           (None, 2)                 202
#
# =================================================================
# Total params: 7,852
# Trainable params: 7,852
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.predict(X_test)[0]
# Out:
# 58/58 [==============================] - 1s 10ms/step
# array([1.0000000e+00, 4.7968434e-09], dtype=float32)

# %%
np.argmax(model.predict(X_test)[0])
# Out:
# 58/58 [==============================] - 1s 10ms/step
# 0
