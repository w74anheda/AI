# %% [markdown]
# # RNN (Recurrent neural network) :
# ### is good for sequenced (Text, Time Series) problem
# <img src="../../img/RNN-vs-LSTM-vs-GRU-1200x361.png">
# <img src="../../img/1 d_POV7c8fzHbKuTgJzCxtA.gif">
# <img src="../../img/rnn_rel.jpeg">

# %%
import numpy as np
import pandas as pd
import random
import matplotlib.pyplot as PLT
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,SimpleRNN,Dropout,LSTM,GRU,BatchNormalization
from sklearn.model_selection import train_test_split
from sklearn.model_selection import train_test_split
from sklearn import metrics

# %% [markdown]
# # Simple RNN

# %%
t = np.arange(0,2000)
x = np.sin( .01* t)
X_train,X_test= x[:1500],x[1500:]

# %%
XTrain,YTrain = [],[]
XTest,YTest = [],[]
seq = 5

for start in range(len(X_train)- seq):
    end = start + seq
    XTrain.append(X_train[start:end,])
    YTrain.append(X_train[end])
    
for start in range(len(X_test)- seq):
    end = start + seq
    XTest.append(X_test[start:end,])
    YTest.append(X_test[end])
    
X_train, X_test, Y_train, Y_test = np.array(XTrain), np.array(XTest), np.array(YTrain), np.array(YTest)
X_train = np.reshape( X_train,(X_train.shape[0],X_train.shape[1],1) )
X_test = np.reshape( X_test,(X_test.shape[0],X_test.shape[1],1) )

# %%
PLT.plot(x)

# %%
model = Sequential()
model.add(SimpleRNN(units=64, activation='tanh'))
model.add(Dense(1))

model.compile(loss='mean_absolute_error',optimizer='adam')

# %%
history = model.fit(X_train,Y_train, epochs=100,batch_size=20)
# Out:
# Epoch 1/100
# 75/75 [==============================] - 2s 4ms/step - loss: 0.0682
# Epoch 2/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0232
# Epoch 3/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0140
# Epoch 4/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0181
# Epoch 5/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0098
# Epoch 6/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0138
# Epoch 7/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0076
# Epoch 8/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0110
# Epoch 9/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0108
# Epoch 10/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0090
# Epoch 11/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0125
# Epoch 12/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0067
# Epoch 13/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0137
# Epoch 14/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0079
# Epoch 15/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0051
# Epoch 16/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0063
# Epoch 17/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0077
# Epoch 18/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0068
# Epoch 19/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0069
# Epoch 20/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0049
# Epoch 21/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0051
# Epoch 22/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0073
# Epoch 23/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0049
# Epoch 24/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0057
# Epoch 25/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0047
# Epoch 26/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0034
# Epoch 27/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0032
# Epoch 28/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0037
# Epoch 29/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0056
# Epoch 30/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0044
# Epoch 31/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0051
# Epoch 32/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0036
# Epoch 33/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0042
# Epoch 34/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0041
# Epoch 35/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0048
# Epoch 36/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0045
# Epoch 37/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0038
# Epoch 38/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0030
# Epoch 39/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0045
# Epoch 40/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0050
# Epoch 41/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0047
# Epoch 42/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0023
# Epoch 43/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0039
# Epoch 44/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0039
# Epoch 45/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0035
# Epoch 46/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0030
# Epoch 47/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0042
# Epoch 48/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0028
# Epoch 49/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0042
# Epoch 50/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0023
# Epoch 51/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0034
# Epoch 52/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0041
# Epoch 53/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0025
# Epoch 54/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0033
# Epoch 55/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0030
# Epoch 56/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0035
# Epoch 57/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0028
# Epoch 58/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0019
# Epoch 59/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0033
# Epoch 60/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0045
# Epoch 61/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0023
# Epoch 62/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0029
# Epoch 63/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0027
# Epoch 64/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0022
# Epoch 65/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0024
# Epoch 66/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0020
# Epoch 67/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0030
# Epoch 68/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0026
# Epoch 69/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0020
# Epoch 70/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0028
# Epoch 71/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0024
# Epoch 72/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0029
# Epoch 73/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0026
# Epoch 74/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0018
# Epoch 75/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0026
# Epoch 76/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0032
# Epoch 77/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0019
# Epoch 78/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0023
# Epoch 79/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0032
# Epoch 80/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0021
# Epoch 81/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0024
# Epoch 82/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0029
# Epoch 83/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0029
# Epoch 84/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0026
# Epoch 85/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0028
# Epoch 86/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0024
# Epoch 87/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0027
# Epoch 88/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0022
# Epoch 89/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0018
# Epoch 90/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0018
# Epoch 91/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0027
# Epoch 92/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0032
# Epoch 93/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0024
# Epoch 94/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0021
# Epoch 95/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0025
# Epoch 96/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0021
# Epoch 97/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0027
# Epoch 98/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0018
# Epoch 99/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0033
# Epoch 100/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0025

# %%
model.evaluate(X_test,Y_test) # return mean absolute error
# Out:
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0023
# 0.002302355831488967

# %%
X_train_predicted = model.predict(X_train)
X_test_predicted = model.predict(X_test)
X_final = np.concatenate([X_train_predicted,X_test_predicted],axis=0)
# Out:
# 47/47 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 3ms/step

# %%
PLT.plot(x, c='blue')
PLT.plot(X_final, c='red')

# %% [markdown]
# # Simple RNN predict Foolad

# %%
DF = pd.read_csv('../../../datasets/foolad.csv')
DF = DF.sort_values(by='<DTYYYYMMDD>').reset_index(drop=True)
DF['<DTYYYYMMDD>'] = DF['<DTYYYYMMDD>'].apply(lambda date: ''.join([ f'{v}-' if i in [3,5] else v for (i,v) in enumerate(str(date)) ]))
DF['<DTYYYYMMDD>'] = pd.to_datetime(DF['<DTYYYYMMDD>'])
DF.rename(columns={
    '<DTYYYYMMDD>' : 'Date',
    '<FIRST>':'Open',
    '<HIGH>':'High',
    '<LOW>':'Low',
    '<CLOSE>':'Close',
    '<VALUE>':'Volume',
},inplace=True)
DF.set_index('Date',inplace=True)
DF = DF[['Open','High','Low','Close','Volume']]
DF.head()
# Out:
#               Open    High     Low   Close        Volume
# Date
# 2007-03-11  1900.0  1938.0  1900.0  1900.0  889437216900
# 2007-03-12  1938.0  1938.0  1938.0  1938.0  193879458000
# 2007-03-13  1976.0  1976.0  1915.0  1973.0  249241504527
# 2007-03-14  1934.0  1966.0  1934.0  1934.0   51666379451
# 2007-03-17  1896.0  1927.0  1896.0  1898.0   28239006789

# %%
DF.describe()
# Out:
#                open          high           low         Close        volume
# count   3472.000000   3472.000000   3472.000000   3472.000000  3.472000e+03
# mean    4422.748272   4493.065956   4345.216302   4423.048387  4.052514e+11
# std     3767.136998   3847.462530   3673.937748   3759.742410  1.321266e+12
# min     1000.000000   1007.000000    950.000000   1001.000000  6.591940e+05
# 25%     2050.000000   2070.000000   2024.750000   2047.000000  9.493189e+09
# 50%     3089.000000   3133.000000   3051.000000   3095.500000  3.365174e+10
# 75%     4676.500000   4738.250000   4575.500000   4668.250000  2.095307e+11
# max    23400.000000  24820.000000  22900.000000  23640.000000  2.011022e+13

# %%
DF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3019 entries, 0 to 3018
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    3019 non-null   object
#  1   Open    3019 non-null   float64
#  2   High    3019 non-null   float64
#  3   Low     3019 non-null   float64
#  4   Close   3019 non-null   float64
#  5   Volume  3019 non-null   int64
#  6   Name    3019 non-null   object
# dtypes: float64(4), int64(1), object(2)
# memory usage: 165.2+ KB

# %%
PLT.figure(figsize=(15,5))
PLT.plot(DF['Close'])

# %%
data = DF['Close'].values
X_train,X_test = data[:2500],data[2500:]

# %%
XTrain,YTrain = [],[]
XTest,YTest = [],[]
seq = 30

for start in range(len(X_train)- seq):
    end = start + seq
    XTrain.append(X_train[start:end,])
    YTrain.append(X_train[end])
    
for start in range(len(X_test)- seq):
    end = start + seq
    XTest.append(X_test[start:end,])
    YTest.append(X_test[end])
    
X_train, X_test, Y_train, Y_test = np.array(XTrain), np.array(XTest), np.array(YTrain), np.array(YTest)
X_train = np.reshape( X_train,(X_train.shape[0],X_train.shape[1],1) )
X_test = np.reshape( X_test,(X_test.shape[0],X_test.shape[1],1) )

# %%
model = Sequential()
model.add(GRU(units=64, activation='relu')) # tanh
model.add(Dense(100))
model.add(Dropout(.5))
model.add(Dense(10))
model.add(Dense(1))
model.compile(loss='mean_absolute_error',optimizer='adam')

# %%
history = model.fit(X_train,Y_train, epochs=50,batch_size=50)
# Out:
# Epoch 1/50
# 50/50 [==============================] - 3s 20ms/step - loss: 878.9865
# Epoch 2/50
# 50/50 [==============================] - 1s 20ms/step - loss: 325.8197
# Epoch 3/50
# 50/50 [==============================] - 1s 20ms/step - loss: 269.0964
# Epoch 4/50
# 50/50 [==============================] - 1s 21ms/step - loss: 255.9626
# Epoch 5/50
# 50/50 [==============================] - 1s 20ms/step - loss: 239.8793
# Epoch 6/50
# 50/50 [==============================] - 1s 19ms/step - loss: 234.9064
# Epoch 7/50
# 50/50 [==============================] - 1s 20ms/step - loss: 233.8591
# Epoch 8/50
# 50/50 [==============================] - 1s 20ms/step - loss: 234.1879
# Epoch 9/50
# 50/50 [==============================] - 1s 20ms/step - loss: 231.4865
# Epoch 10/50
# 50/50 [==============================] - 1s 19ms/step - loss: 230.2651
# Epoch 11/50
# 50/50 [==============================] - 1s 19ms/step - loss: 225.2422
# Epoch 12/50
# 50/50 [==============================] - 1s 20ms/step - loss: 219.7221
# Epoch 13/50
# 50/50 [==============================] - 1s 20ms/step - loss: 228.3189
# Epoch 14/50
# 50/50 [==============================] - 1s 19ms/step - loss: 230.0869
# Epoch 15/50
# 50/50 [==============================] - 1s 19ms/step - loss: 224.0860
# Epoch 16/50
# 50/50 [==============================] - 1s 19ms/step - loss: 225.5752
# Epoch 17/50
# 50/50 [==============================] - 1s 20ms/step - loss: 226.6750
# Epoch 18/50
# 50/50 [==============================] - 1s 19ms/step - loss: 223.1452
# Epoch 19/50
# 50/50 [==============================] - 1s 19ms/step - loss: 225.0947
# Epoch 20/50
# 50/50 [==============================] - 1s 20ms/step - loss: 230.5359
# Epoch 21/50
# 50/50 [==============================] - 1s 19ms/step - loss: 226.6374
# Epoch 22/50
# 50/50 [==============================] - 1s 20ms/step - loss: 220.8907
# Epoch 23/50
# 50/50 [==============================] - 1s 20ms/step - loss: 228.8311
# Epoch 24/50
# 50/50 [==============================] - 1s 20ms/step - loss: 223.7886
# Epoch 25/50
# 50/50 [==============================] - 1s 20ms/step - loss: 219.1780
# Epoch 26/50
# 50/50 [==============================] - 1s 20ms/step - loss: 231.4427
# Epoch 27/50
# 50/50 [==============================] - 1s 21ms/step - loss: 223.1087
# Epoch 28/50
# 50/50 [==============================] - 1s 19ms/step - loss: 228.7525
# Epoch 29/50
# 50/50 [==============================] - 1s 20ms/step - loss: 221.7964
# Epoch 30/50
# 50/50 [==============================] - 1s 24ms/step - loss: 229.6710
# Epoch 31/50
# 50/50 [==============================] - 1s 22ms/step - loss: 226.3704
# Epoch 32/50
# 50/50 [==============================] - 1s 22ms/step - loss: 221.3520
# Epoch 33/50
# 50/50 [==============================] - 1s 25ms/step - loss: 224.1920
# Epoch 34/50
# 50/50 [==============================] - 1s 24ms/step - loss: 227.1305
# Epoch 35/50
# 50/50 [==============================] - 1s 24ms/step - loss: 233.4101
# Epoch 36/50
# 50/50 [==============================] - 1s 23ms/step - loss: 227.9101
# Epoch 37/50
# 50/50 [==============================] - 1s 21ms/step - loss: 223.4088
# Epoch 38/50
# 50/50 [==============================] - 1s 22ms/step - loss: 231.0605
# Epoch 39/50
# 50/50 [==============================] - 1s 21ms/step - loss: 234.1342
# Epoch 40/50
# 50/50 [==============================] - 1s 22ms/step - loss: 225.1538
# Epoch 41/50
# 50/50 [==============================] - 1s 20ms/step - loss: 221.5994
# Epoch 42/50
# 50/50 [==============================] - 1s 21ms/step - loss: 227.9844
# Epoch 43/50
# 50/50 [==============================] - 1s 23ms/step - loss: 229.2544
# Epoch 44/50
# 50/50 [==============================] - 1s 20ms/step - loss: 225.8901
# Epoch 45/50
# 50/50 [==============================] - 1s 20ms/step - loss: 227.0870
# Epoch 46/50
# 50/50 [==============================] - 1s 21ms/step - loss: 230.5166
# Epoch 47/50
# 50/50 [==============================] - 1s 20ms/step - loss: 232.0197
# Epoch 48/50
# 50/50 [==============================] - 1s 20ms/step - loss: 230.4764
# Epoch 49/50
# 50/50 [==============================] - 1s 21ms/step - loss: 227.2340
# Epoch 50/50
# 50/50 [==============================] - 1s 22ms/step - loss: 225.5314

# %%
model.evaluate(X_test,Y_test) # return mean absolute error
# Out:
# 30/30 [==============================] - 1s 7ms/step - loss: 198.7165
# 198.71652221679688

# %%
X_train_predicted = model.predict(X_train)
X_test_predicted = model.predict(X_test)
X_final = np.concatenate([X_train_predicted,X_test_predicted],axis=0)
# Out:
# 78/78 [==============================] - 1s 7ms/step
# 30/30 [==============================] - 0s 7ms/step

# %%
PLT.figure(figsize=(15,5))

PLT.plot(data, c='blue')
PLT.plot(X_final, c='red')

# %% [markdown]
# # Currency Prediction

# %%
from collections import deque
from sklearn import preprocessing
import datetime as dt
import pandas_datareader as web

# %%
FOOLAD = DF.copy()

# %%
start = dt.datetime(2018,1,1)
end = dt.datetime.now()
DOGE = web.DataReader('DOGE-USD', 'yahoo', start, end)
DOGE = DOGE.reset_index()
DOGE['Date'] = pd.to_datetime(DOGE['Date'])
DOGE = DOGE.rename(columns={'Date':'Date'})
DOGE.drop(columns=['Adj Close'],inplace=True)
DOGE.set_index('Date',inplace=True)

# %%
# FOOLAD.fillna(method='ffill')

# %%
DF = DOGE.copy()

# %%
DF['future'] = DF['Close'].shift(-3)

# %%
DF.head()
# Out:
#                 High       Low      Open     Close     Volume    future
# Date
# 2018-01-01  0.009063  0.008101  0.009031  0.008909   50616900  0.009644
# 2018-01-02  0.009598  0.008551  0.008873  0.009145   89424096  0.012167
# 2018-01-03  0.009584  0.008882  0.009088  0.009320   66349900  0.014863
# 2018-01-04  0.010036  0.008768  0.009346  0.009644  108986000  0.017088
# 2018-01-05  0.012283  0.009589  0.009660  0.012167  212383008  0.015045

# %%
def compare(future,current):
    return 1 if future > current else 0
DF['target'] = list(map(compare, DF['future'], DF['Close']))

# %%
DF.head()
# Out:
#                 High       Low      Open     Close     Volume    future  \
# Date
# 2018-01-01  0.009063  0.008101  0.009031  0.008909   50616900  0.009644
# 2018-01-02  0.009598  0.008551  0.008873  0.009145   89424096  0.012167
# 2018-01-03  0.009584  0.008882  0.009088  0.009320   66349900  0.014863
# 2018-01-04  0.010036  0.008768  0.009346  0.009644  108986000  0.017088
# 2018-01-05  0.012283  0.009589  0.009660  0.012167  212383008  0.015045
#
#             target
# Date
# 2018-01-01       1
# 2018-01-02       1
# 2018-01-03       1
# 2018-01-04       1
# 2018-01-05       1

# %%
def preprocess_currency(DF,COLS,seq):
    DF = DF.copy()
    for c in COLS:
        DF[c] = DF[c].pct_change()
        DF.dropna(inplace=True)
        DF[c] = preprocessing.scale(DF[c])
    DF.dropna(inplace=True)
    sequences = []
    prev_days = deque(maxlen=seq)
    for i in DF.values:
        prev_days.append(i[:-2])
        if len(prev_days) == seq:
            sequences.append([np.array(prev_days),i[-1]])
#     print(sequences)        
    random.shuffle(sequences)
    buys = []
    sells= []
    for sequence, target in sequences:
        if target == 0:
            sells.append([sequence,target])
        else :
            buys.append([sequence,target])
    random.shuffle(buys)
    random.shuffle(sells)
    
    lower = min(len(buys), len(sells))
    buys = buys[:lower]
    sells = sells[:lower]
    sequences = buys+sells
    random.shuffle(sequences)
    X = []
    Y = []
    for seq, target in sequences:
        X.append(seq)
        Y.append(target)
    return np.array(X), np.array(Y)

# %%
DF_train, DF_test = train_test_split(DF,test_size=.4,shuffle=False)

# %%
seq = 90
X_COLS = DF.columns.difference(['future','target'])
                               
X_train, Y_train = preprocess_currency(DF_train,X_COLS,seq)
X_test, Y_test = preprocess_currency(DF_test,X_COLS,seq)
# X_train.shape

# %%
model = Sequential()
model.add( 
    GRU(units=32,
         input_shape=(X_train.shape[1:]),
         activation='relu',
         return_sequences=True
        ) 
) 
model.add(BatchNormalization())
model.add(GRU(units=12,activation='relu',)) 
# model.add(Dense(100))
# model.add(Dropout(.5))
model.add(BatchNormalization())
model.add(Dense(10))
model.add(BatchNormalization())
model.add(Dense(2, activation='softmax'))
model.compile(loss='sparse_categorical_crossentropy',optimizer='Adam', metrics=['accuracy'])

# %%
history = model.fit(X_train,Y_train, epochs=100,batch_size=50, validation_data=(X_test,Y_test) )
# Out:
# Epoch 1/100
# 18/18 [==============================] - 7s 135ms/step - loss: 0.7926 - accuracy: 0.5161 - val_loss: 0.6927 - val_accuracy: 0.4878
# Epoch 2/100
# 18/18 [==============================] - 2s 116ms/step - loss: 0.7106 - accuracy: 0.5298 - val_loss: 0.6936 - val_accuracy: 0.5243
# Epoch 3/100
# 18/18 [==============================] - 2s 118ms/step - loss: 0.6854 - accuracy: 0.5528 - val_loss: 0.6939 - val_accuracy: 0.5122
# Epoch 4/100
# 18/18 [==============================] - 2s 120ms/step - loss: 0.6690 - accuracy: 0.5872 - val_loss: 0.6944 - val_accuracy: 0.5087
# Epoch 5/100
# 18/18 [==============================] - 2s 118ms/step - loss: 0.6602 - accuracy: 0.6021 - val_loss: 0.6940 - val_accuracy: 0.5104
# Epoch 6/100
# 18/18 [==============================] - 2s 112ms/step - loss: 0.6565 - accuracy: 0.6089 - val_loss: 0.6936 - val_accuracy: 0.5069
# Epoch 7/100
# 18/18 [==============================] - 2s 121ms/step - loss: 0.6429 - accuracy: 0.6284 - val_loss: 0.6933 - val_accuracy: 0.5104
# Epoch 8/100
# 18/18 [==============================] - 2s 124ms/step - loss: 0.6339 - accuracy: 0.6353 - val_loss: 0.6932 - val_accuracy: 0.5191
# Epoch 9/100
# 18/18 [==============================] - 2s 116ms/step - loss: 0.6223 - accuracy: 0.6525 - val_loss: 0.6924 - val_accuracy: 0.5174
# Epoch 10/100
# 18/18 [==============================] - 2s 105ms/step - loss: 0.6061 - accuracy: 0.6732 - val_loss: 0.6914 - val_accuracy: 0.5417
# Epoch 11/100
# 18/18 [==============================] - 2s 115ms/step - loss: 0.5912 - accuracy: 0.6881 - val_loss: 0.6914 - val_accuracy: 0.5278
# Epoch 12/100
# 18/18 [==============================] - 2s 109ms/step - loss: 0.5884 - accuracy: 0.6778 - val_loss: 0.6906 - val_accuracy: 0.5312
# Epoch 13/100
# 18/18 [==============================] - 2s 124ms/step - loss: 0.5729 - accuracy: 0.6869 - val_loss: 0.6898 - val_accuracy: 0.5399
# Epoch 14/100
# 18/18 [==============================] - 2s 107ms/step - loss: 0.5661 - accuracy: 0.7018 - val_loss: 0.6891 - val_accuracy: 0.5434
# Epoch 15/100
# 18/18 [==============================] - 2s 107ms/step - loss: 0.5515 - accuracy: 0.7122 - val_loss: 0.6882 - val_accuracy: 0.5417
# Epoch 16/100
# 18/18 [==============================] - 2s 107ms/step - loss: 0.5376 - accuracy: 0.7397 - val_loss: 0.6882 - val_accuracy: 0.5521
# Epoch 17/100
# 18/18 [==============================] - 2s 107ms/step - loss: 0.5157 - accuracy: 0.7443 - val_loss: 0.6872 - val_accuracy: 0.5556
# Epoch 18/100
# 18/18 [==============================] - 2s 108ms/step - loss: 0.5184 - accuracy: 0.7489 - val_loss: 0.6973 - val_accuracy: 0.5330
# Epoch 19/100
# 18/18 [==============================] - 2s 126ms/step - loss: 0.5040 - accuracy: 0.7431 - val_loss: 0.6968 - val_accuracy: 0.5382
# Epoch 20/100
# 18/18 [==============================] - 2s 122ms/step - loss: 0.4959 - accuracy: 0.7615 - val_loss: 0.6851 - val_accuracy: 0.5556
# Epoch 21/100
# 18/18 [==============================] - 2s 106ms/step - loss: 0.4747 - accuracy: 0.7787 - val_loss: 0.6940 - val_accuracy: 0.5538
# Epoch 22/100
# 18/18 [==============================] - 2s 107ms/step - loss: 0.4714 - accuracy: 0.7706 - val_loss: 0.7260 - val_accuracy: 0.4983
# Epoch 23/100
# 18/18 [==============================] - 2s 109ms/step - loss: 0.4696 - accuracy: 0.7626 - val_loss: 0.7757 - val_accuracy: 0.5278
# Epoch 24/100
# 18/18 [==============================] - 2s 107ms/step - loss: 0.4401 - accuracy: 0.7947 - val_loss: 0.7141 - val_accuracy: 0.5312
# Epoch 25/100
# 18/18 [==============================] - 2s 107ms/step - loss: 0.4345 - accuracy: 0.8016 - val_loss: 0.7080 - val_accuracy: 0.5764
# Epoch 26/100
# 18/18 [==============================] - 2s 107ms/step - loss: 0.4311 - accuracy: 0.8028 - val_loss: 0.7092 - val_accuracy: 0.5799
# Epoch 27/100
# 18/18 [==============================] - 2s 109ms/step - loss: 0.4122 - accuracy: 0.8073 - val_loss: 0.7161 - val_accuracy: 0.5781
# Epoch 28/100
# 18/18 [==============================] - 2s 106ms/step - loss: 0.4098 - accuracy: 0.8177 - val_loss: 0.7349 - val_accuracy: 0.5625
# Epoch 29/100
# 18/18 [==============================] - 2s 107ms/step - loss: 0.4071 - accuracy: 0.8154 - val_loss: 0.7311 - val_accuracy: 0.5694
# Epoch 30/100
# 18/18 [==============================] - 2s 106ms/step - loss: 0.4043 - accuracy: 0.8142 - val_loss: 0.9161 - val_accuracy: 0.5104
# Epoch 31/100
# 18/18 [==============================] - 2s 107ms/step - loss: 0.3979 - accuracy: 0.8200 - val_loss: 1.0073 - val_accuracy: 0.5208
# Epoch 32/100
# 18/18 [==============================] - 2s 111ms/step - loss: 0.3863 - accuracy: 0.8417 - val_loss: 0.8848 - val_accuracy: 0.5312
# Epoch 33/100
# 18/18 [==============================] - 2s 108ms/step - loss: 0.3705 - accuracy: 0.8486 - val_loss: 0.8030 - val_accuracy: 0.5590
# Epoch 34/100
# 18/18 [==============================] - 2s 109ms/step - loss: 0.3655 - accuracy: 0.8521 - val_loss: 0.8733 - val_accuracy: 0.5260
# Epoch 35/100
# 18/18 [==============================] - 2s 116ms/step - loss: 0.3446 - accuracy: 0.8532 - val_loss: 0.9336 - val_accuracy: 0.5243
# Epoch 36/100
# 18/18 [==============================] - 2s 123ms/step - loss: 0.3480 - accuracy: 0.8612 - val_loss: 1.0350 - val_accuracy: 0.5642
# Epoch 37/100
# 18/18 [==============================] - 2s 138ms/step - loss: 0.3333 - accuracy: 0.8624 - val_loss: 0.8798 - val_accuracy: 0.5469
# Epoch 38/100
# 18/18 [==============================] - 2s 120ms/step - loss: 0.3417 - accuracy: 0.8498 - val_loss: 1.1783 - val_accuracy: 0.5087
# Epoch 39/100
# 18/18 [==============================] - 2s 112ms/step - loss: 0.3221 - accuracy: 0.8693 - val_loss: 0.9226 - val_accuracy: 0.5521
# Epoch 40/100
# 18/18 [==============================] - 2s 110ms/step - loss: 0.3156 - accuracy: 0.8704 - val_loss: 0.9703 - val_accuracy: 0.5694
# Epoch 41/100
# 18/18 [==============================] - 2s 109ms/step - loss: 0.3457 - accuracy: 0.8475 - val_loss: 1.4610 - val_accuracy: 0.5104
# Epoch 42/100
# 18/18 [==============================] - 2s 111ms/step - loss: 0.3431 - accuracy: 0.8521 - val_loss: 1.1032 - val_accuracy: 0.5608
# Epoch 43/100
# 18/18 [==============================] - 2s 109ms/step - loss: 0.3097 - accuracy: 0.8681 - val_loss: 1.0045 - val_accuracy: 0.5573
# Epoch 44/100
# 18/18 [==============================] - 2s 110ms/step - loss: 0.2907 - accuracy: 0.8784 - val_loss: 0.9948 - val_accuracy: 0.5382
# Epoch 45/100
# 18/18 [==============================] - 2s 110ms/step - loss: 0.2878 - accuracy: 0.8830 - val_loss: 1.0087 - val_accuracy: 0.5347
# Epoch 46/100
# 18/18 [==============================] - 2s 121ms/step - loss: 0.3009 - accuracy: 0.8830 - val_loss: 1.1081 - val_accuracy: 0.5295
# Epoch 47/100
# 18/18 [==============================] - 2s 116ms/step - loss: 0.2899 - accuracy: 0.8796 - val_loss: 1.0612 - val_accuracy: 0.5451
# Epoch 48/100
# 18/18 [==============================] - 2s 123ms/step - loss: 0.2854 - accuracy: 0.8727 - val_loss: 1.4705 - val_accuracy: 0.5191
# Epoch 49/100
# 18/18 [==============================] - 2s 123ms/step - loss: 0.2811 - accuracy: 0.8933 - val_loss: 1.1222 - val_accuracy: 0.5608
# Epoch 50/100
# 18/18 [==============================] - 2s 110ms/step - loss: 0.2841 - accuracy: 0.8750 - val_loss: 1.1576 - val_accuracy: 0.5278
# Epoch 51/100
# 18/18 [==============================] - 2s 111ms/step - loss: 0.2942 - accuracy: 0.8865 - val_loss: 1.1394 - val_accuracy: 0.5625
# Epoch 52/100
# 18/18 [==============================] - 2s 111ms/step - loss: 0.2902 - accuracy: 0.8784 - val_loss: 1.4106 - val_accuracy: 0.5608
# Epoch 53/100
# 18/18 [==============================] - 2s 108ms/step - loss: 0.2784 - accuracy: 0.8784 - val_loss: 1.1712 - val_accuracy: 0.5503
# Epoch 54/100
# 18/18 [==============================] - 2s 110ms/step - loss: 0.2686 - accuracy: 0.8933 - val_loss: 1.2304 - val_accuracy: 0.5434
# Epoch 55/100
# 18/18 [==============================] - 2s 113ms/step - loss: 0.2944 - accuracy: 0.8796 - val_loss: 1.5376 - val_accuracy: 0.5191
# Epoch 56/100
# 18/18 [==============================] - 2s 110ms/step - loss: 0.2722 - accuracy: 0.8922 - val_loss: 1.2837 - val_accuracy: 0.5226
# Epoch 57/100
# 18/18 [==============================] - 2s 111ms/step - loss: 0.2399 - accuracy: 0.9071 - val_loss: 1.2161 - val_accuracy: 0.5243
# Epoch 58/100
# 18/18 [==============================] - 2s 112ms/step - loss: 0.2325 - accuracy: 0.9037 - val_loss: 1.2876 - val_accuracy: 0.5243
# Epoch 59/100
# 18/18 [==============================] - 2s 121ms/step - loss: 0.2595 - accuracy: 0.9014 - val_loss: 1.3613 - val_accuracy: 0.5087
# Epoch 60/100
# 18/18 [==============================] - 2s 115ms/step - loss: 0.2467 - accuracy: 0.8991 - val_loss: 1.6547 - val_accuracy: 0.5139
# Epoch 61/100
# 18/18 [==============================] - 2s 120ms/step - loss: 0.2319 - accuracy: 0.9174 - val_loss: 1.5590 - val_accuracy: 0.5243
# Epoch 62/100
# 18/18 [==============================] - 2s 110ms/step - loss: 0.2281 - accuracy: 0.9163 - val_loss: 1.5627 - val_accuracy: 0.5191
# Epoch 63/100
# 18/18 [==============================] - 2s 110ms/step - loss: 0.2469 - accuracy: 0.8899 - val_loss: 1.3490 - val_accuracy: 0.5486
# Epoch 64/100
# 18/18 [==============================] - 2s 109ms/step - loss: 0.2442 - accuracy: 0.9060 - val_loss: 1.4382 - val_accuracy: 0.5035
# Epoch 65/100
# 18/18 [==============================] - 2s 111ms/step - loss: 0.2167 - accuracy: 0.9255 - val_loss: 1.3771 - val_accuracy: 0.5382
# Epoch 66/100
# 18/18 [==============================] - 2s 110ms/step - loss: 0.2339 - accuracy: 0.9002 - val_loss: 1.5050 - val_accuracy: 0.5486
# Epoch 67/100
# 18/18 [==============================] - 2s 111ms/step - loss: 0.2320 - accuracy: 0.9106 - val_loss: 1.4210 - val_accuracy: 0.5451
# Epoch 68/100
# 18/18 [==============================] - 2s 113ms/step - loss: 0.1975 - accuracy: 0.9266 - val_loss: 1.4417 - val_accuracy: 0.5139
# Epoch 69/100
# 18/18 [==============================] - 2s 110ms/step - loss: 0.2004 - accuracy: 0.9197 - val_loss: 1.4860 - val_accuracy: 0.5417
# Epoch 70/100
# 18/18 [==============================] - 2s 110ms/step - loss: 0.2258 - accuracy: 0.9060 - val_loss: 1.8458 - val_accuracy: 0.5035
# Epoch 71/100
# 18/18 [==============================] - 2s 108ms/step - loss: 0.2235 - accuracy: 0.9140 - val_loss: 1.4727 - val_accuracy: 0.5330
# Epoch 72/100
# 18/18 [==============================] - 2s 109ms/step - loss: 0.2021 - accuracy: 0.9220 - val_loss: 1.6071 - val_accuracy: 0.5052
# Epoch 73/100
# 18/18 [==============================] - 2s 109ms/step - loss: 0.2202 - accuracy: 0.9106 - val_loss: 2.0317 - val_accuracy: 0.5087
# Epoch 74/100
# 18/18 [==============================] - 2s 117ms/step - loss: 0.2226 - accuracy: 0.9220 - val_loss: 1.6650 - val_accuracy: 0.5260
# Epoch 75/100
# 18/18 [==============================] - 2s 117ms/step - loss: 0.1932 - accuracy: 0.9369 - val_loss: 1.5899 - val_accuracy: 0.5399
# Epoch 76/100
# 18/18 [==============================] - 2s 126ms/step - loss: 0.2110 - accuracy: 0.9048 - val_loss: 1.5176 - val_accuracy: 0.5365
# Epoch 77/100
# 18/18 [==============================] - 2s 111ms/step - loss: 0.1924 - accuracy: 0.9186 - val_loss: 2.2357 - val_accuracy: 0.5087
# Epoch 78/100
# 18/18 [==============================] - 2s 107ms/step - loss: 0.1823 - accuracy: 0.9289 - val_loss: 1.5621 - val_accuracy: 0.5330
# Epoch 79/100
# 18/18 [==============================] - 2s 109ms/step - loss: 0.1787 - accuracy: 0.9346 - val_loss: 1.5745 - val_accuracy: 0.5365
# Epoch 80/100
# 18/18 [==============================] - 2s 111ms/step - loss: 0.1995 - accuracy: 0.9220 - val_loss: 2.4120 - val_accuracy: 0.5139
# Epoch 81/100
# 18/18 [==============================] - 2s 120ms/step - loss: 0.1727 - accuracy: 0.9404 - val_loss: 2.2808 - val_accuracy: 0.5208
# Epoch 82/100
# 18/18 [==============================] - 2s 115ms/step - loss: 0.1858 - accuracy: 0.9209 - val_loss: 2.2287 - val_accuracy: 0.5087
# Epoch 83/100
# 18/18 [==============================] - 2s 128ms/step - loss: 0.2076 - accuracy: 0.9140 - val_loss: 1.8043 - val_accuracy: 0.5451
# Epoch 84/100
# 18/18 [==============================] - 2s 109ms/step - loss: 0.2078 - accuracy: 0.9106 - val_loss: 1.7573 - val_accuracy: 0.5191
# Epoch 85/100
# 18/18 [==============================] - 2s 109ms/step - loss: 0.1835 - accuracy: 0.9232 - val_loss: 2.3475 - val_accuracy: 0.5174
# Epoch 86/100
# 18/18 [==============================] - 2s 109ms/step - loss: 0.1627 - accuracy: 0.9404 - val_loss: 1.8788 - val_accuracy: 0.5365
# Epoch 87/100
# 18/18 [==============================] - 2s 109ms/step - loss: 0.1823 - accuracy: 0.9289 - val_loss: 2.9230 - val_accuracy: 0.5503
# Epoch 88/100
# 18/18 [==============================] - 2s 108ms/step - loss: 0.2061 - accuracy: 0.9163 - val_loss: 1.6783 - val_accuracy: 0.5208
# Epoch 89/100
# 18/18 [==============================] - 2s 107ms/step - loss: 0.1767 - accuracy: 0.9346 - val_loss: 2.2033 - val_accuracy: 0.5122
# Epoch 90/100
# 18/18 [==============================] - 2s 108ms/step - loss: 0.1666 - accuracy: 0.9369 - val_loss: 1.7054 - val_accuracy: 0.5347
# Epoch 91/100
# 18/18 [==============================] - 2s 110ms/step - loss: 0.1498 - accuracy: 0.9495 - val_loss: 1.7301 - val_accuracy: 0.5312
# Epoch 92/100
# 18/18 [==============================] - 2s 123ms/step - loss: 0.1412 - accuracy: 0.9450 - val_loss: 1.8872 - val_accuracy: 0.5260
# Epoch 93/100
# 18/18 [==============================] - 2s 120ms/step - loss: 0.1584 - accuracy: 0.9392 - val_loss: 1.8097 - val_accuracy: 0.5434
# Epoch 94/100
# 18/18 [==============================] - 2s 115ms/step - loss: 0.1527 - accuracy: 0.9415 - val_loss: 1.7962 - val_accuracy: 0.5469
# Epoch 95/100
# 18/18 [==============================] - 2s 114ms/step - loss: 0.1847 - accuracy: 0.9278 - val_loss: 1.8647 - val_accuracy: 0.5365
# Epoch 96/100
# 18/18 [==============================] - 2s 116ms/step - loss: 0.1655 - accuracy: 0.9335 - val_loss: 1.9196 - val_accuracy: 0.5174
# Epoch 97/100
# 18/18 [==============================] - 2s 116ms/step - loss: 0.1507 - accuracy: 0.9472 - val_loss: 2.2607 - val_accuracy: 0.5087
# Epoch 98/100
# 18/18 [==============================] - 2s 114ms/step - loss: 0.1818 - accuracy: 0.9243 - val_loss: 1.8454 - val_accuracy: 0.5278
# Epoch 99/100
# 18/18 [==============================] - 2s 111ms/step - loss: 0.1326 - accuracy: 0.9507 - val_loss: 1.8475 - val_accuracy: 0.5174
# Epoch 100/100
# 18/18 [==============================] - 2s 114ms/step - loss: 0.1388 - accuracy: 0.9415 - val_loss: 1.8071 - val_accuracy: 0.5451

# %%
Y_predicted = model.predict(X_test)
Y_predicted = [np.argmax(x) for x in Y_predicted]
# Y_predicted = [1 if x[1]>.4 else 0 for x in Y_predicted]

print(metrics.classification_report(Y_test,Y_predicted))
print(metrics.confusion_matrix(Y_test,Y_predicted))
# Out:
# 18/18 [==============================] - 1s 25ms/step
#               precision    recall  f1-score   support
#
#          0.0       0.54      0.55      0.55       288
#          1.0       0.55      0.54      0.54       288
#
#     accuracy                           0.55       576
#    macro avg       0.55      0.55      0.55       576
# weighted avg       0.55      0.55      0.55       576
#
# [[158 130]
#  [132 156]]

# %%
today = DF.iloc[len(DF)-15:,:-2]

# %%
today
# Out:
#                 High       Low      Open     Close      Volume
# Date
# 2022-12-02  0.103260  0.097639  0.101594  0.102148   776013992
# 2022-12-03  0.102823  0.098651  0.102150  0.099824   632114946
# 2022-12-04  0.105264  0.099806  0.099811  0.104286   759219556
# 2022-12-05  0.111012  0.100063  0.104252  0.101474  1051327257
# 2022-12-06  0.102627  0.098508  0.101480  0.100278   534648134
# 2022-12-07  0.100950  0.095017  0.100281  0.095783   622336382
# 2022-12-08  0.098874  0.095367  0.095785  0.098540   492909327
# 2022-12-09  0.099086  0.096001  0.098538  0.096662   423432535
# 2022-12-10  0.097356  0.096258  0.096663  0.096457   242190274
# 2022-12-11  0.097093  0.092668  0.096464  0.092875   300470314
# 2022-12-12  0.093005  0.087288  0.092872  0.090258   749817261
# 2022-12-13  0.094380  0.087718  0.090255  0.090940   766352149
# 2022-12-14  0.092240  0.088244  0.090958  0.088514   549320298
# 2022-12-15  0.088762  0.084419  0.088508  0.084722   412364377
# 2022-12-16  0.086731  0.081909  0.084856  0.082251   511302432

# %%
np.argmax(model.predict(
 [today.values]
))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_3841/910150225.py in <module>
# ----> 1 np.argmax(model.predict(
#       2  [today.values]
#       3 ))
#
# ~/anaconda3/lib/python3.9/site-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# ~/anaconda3/lib/python3.9/site-packages/keras/engine/training.py in tf__predict_function(iterator)
#      13                 try:
#      14                     do_return = True
# ---> 15                     retval_ = ag__.converted_call(ag__.ld(step_function), (ag__.ld(self), ag__.ld(iterator)), None, fscope)
#      16                 except:
#      17                     do_return = False
#
# ValueError: in user code:
#
#     File "/home/masoud/anaconda3/lib/python3.9/site-packages/keras/engine/training.py", line 2137, in predict_function  *
#         return step_function(self, iterator)
#     File "/home/masoud/anaconda3/lib/python3.9/site-packages/keras/engine/training.py", line 2123, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "/home/masoud/anaconda3/lib/python3.9/site-packages/keras/engine/training.py", line 2111, in run_step  **
#         outputs = model.predict_step(data)
#     File "/home/masoud/anaconda3/lib/python3.9/site-packages/keras/engine/training.py", line 2079, in predict_step
#         return self(x, training=False)
#     File "/home/masoud/anaconda3/lib/python3.9/site-packages/keras/utils/traceback_utils.py", line 70, in error_handler
#         raise e.with_traceback(filtered_tb) from None
#     File "/home/masoud/anaconda3/lib/python3.9/site-packages/keras/engine/input_spec.py", line 295, in assert_input_compatibility
#         raise ValueError(
#
#     ValueError: Input 0 of layer "sequential_8" is incompatible with the layer: expected shape=(None, 15, 5), found shape=(None, 5)
