# %%
import numpy as np
import pandas as pd
import os
from scipy import stats
import matplotlib.pyplot as PLT
import seaborn as SB
import random as RANDOM
import statsmodels.api as SM

# %% [markdown]
# # <font color="orange">Continuous Distributions</font>
#   * normal
#   * uniform
#   * exponential

# %%
DT_norm = stats.norm.rvs(size=10000, loc=0, scale=1)
pd.Series(DT_norm).hist(bins=20)
# Out:
# <AxesSubplot:>

# %%
SB.displot(DT_norm, bins=100, kde=True)

# %%
DT_uniform = stats.uniform.rvs(size=10000, loc=0, scale=10)
SB.displot(DT_uniform, kde=True, bins=100)

# %%
DT_exponential = stats.expon.rvs(1/2,size=10000) # mean call time 2 mintue
SB.displot(DT_exponential, kde=True)

# %% [markdown]
# # <font color="orange">Discrete Distributions</font>
#   * bernoli
#   * binomial
#   * multinomial
#   * poisson

# %%
DT_bernoli = stats.bernoulli.rvs(size=10000, p=.3)
SB.displot(DT_bernoli)

# %%
DT_binomial = stats.binom.rvs(size=10000, p=.3, n=100)
SB.displot(DT_binomial)
DT_binomial
# Out:
# array([24, 27, 30, ..., 35, 30, 36])

# %%
icu = 0.3
ccu = 0.1
recovery = 0.6
DT_multinomial = stats.multinomial.rvs(100, [icu,ccu,recovery], size=365)
DT_multinomial = pd.DataFrame(DT_multinomial, columns=['icu','ccu','recovery'])

SB.displot(DT_multinomial, kde=True)

# %%
DT_poisson = stats.poisson.rvs(mu=7, size=1000)
print(DT_poisson)

SB.displot(DT_poisson)
# Out:
# [ 4 11 10  3 11 10 13 13  7  5  7  9  5 14  6  7  9  5  4  5  5 10  5  9
#   6 10  4  9  7  8  5  6  6  5  8  6  4 12  8  6  7  6  5  8 11  8  9 12
#   5  8  7  5  7  5  7  5 12  9  4  4  3  8  5  6  8 13  6  4  7  5  7  7
#   8  6  7  2  8 12 10 13  9  3  6  7  9  7  8  7  5 14  9  7  5  5  7 10
#   7  4  7  4  9  5  5  7  5  9  4 11  5  3  6 10  4  5 10  9  6  7 10  8
#   6  7  4  9  9 11  6  9  3  4 10  3  8  6  7 11  8  8  6  4  6  3  5 12
#  10  8  5  8  8  9  7  3  6  7  7  5  7  6  8  8  9  5  7 11  9  9  5  9
#   7 11  8  6  4  5  5  6  7 11 11  9  5  5  2  6  9  9  5 11  8  5  8  4
#   6 11  4 10  7  5  2  7 11 12  5  7  0 11 10 15  8  5  5  9  4 10  6  2
#   6  7  9  8  5  7  6 10  5  8  2  6  5 13  5  5  5 12  3  7  5  3  5  7
#   5  5  8  3 10  8  8  5  3  8  9  4  5 11  8  3  3  6  7  5 11  3  5 10
#   7  8  6  7  9 11  5  9  8  5  6  4 10 10  7 11  7  2  4 12  7  1  5  5
#   4  5  5  6  6  5 10  8  9  7  5 12 11  6  8  7  4  7  7  9  6  5 10  5
#   6  4  5  8  8  4 11 11  4  5  7  5  7  8  9  3  7  9  8 11  7  8  5  3
#   2 10  8  7 10  9  6  4 10  5  8  6  2  6  3  3  8  2 11  9  5  7  6  9
#   8 10  4 10  6  9  3  7  5  8  5  8  7 11  6 12  6  7  6 10 10 11  2  8
#  10  3  3  9  5 11  7  5  6  4 10 10 10  8 11  5  2  8  5  4 13  6  7 11
#   4  9  6  8  1  9  8  5  2  6  9  5 10  6  4  8  8  3 11  5  7  4  8 12
#  10  7  7  8  6  9  7  5  7  7  8  8  7  8  3  5  6  4  5  6  7  5  3  9
#   4  7  5  9  9  3  8  3  7 10  7  7 13  7  6  7 12  7 12  8  7  4 10  6
#   4  7  7  7  7  5  7  4  7 14  9  7 10  8  2  6  9  6 10  6  5  6  4  5
#  13  8  4  6  8 11 10  4  6  7  6  8  3  4  9  4  8  6  9 10  7  7  7  9
#  11 11  3  9 13 11  4  5  8  5  9  8  8 10  5  4  6  7  7 11  8  8 10  4
#   6  7  8  5  7  3  8  7 12  6  8  7  9 10  6  4  8  8  8  8  7  1  7  8
#   4  9  4  9 12  8  8 10  5  5  5  5  4  5  4  4 10  3 13  8 12  9  6  9
#   5 10  6  8  8  5  9  8  5  4  3  5  3  4  5 10  9  5  4  0  8  5  9  8
#   4  2  3  3  6  7  2  7 16  3  7  6 11  5  3  6  6 11  5  6  8  7  7 17
#   6 12  6 10  4  4  4  8  7 10  3  5  6  2  9 11  7  9  3  5  4  4 12  3
#   7 11  5 10  6  4  3  7  7  9 10  7  9  4 12  7  9  9  5  9  9  6 12  2
#   8  6  7  7  7  7  6  5  7  9 11  6  7  8  5  8  8  5  2  4  9 10  6  7
#   6  5  6  6 10  4  5 10  7  6  6  9  7  8  4  4 11  9  4  9  6  5 10 13
#   7  6  4  8  9  9  5  4  5  5 10  5  7  6 12  6  6  5  7  9  6  8 10  9
#   7  5  4  4  7  7  6  4  8  9  5  4 11 11  9  3  4  4  7  8 14  9  6  8
#  14  7  8  6  7  8  5  4  2  5 10  7  8  3  7  4  6  2  6  4 13  7 13 10
#   9  5  8  5  7  9  9  7  5  2  5  5  8  3  5  7  9  7  7  2  7  4  7  6
#   5  6  9  7  7 10  5 10  9  6 10  8  7  5  7 12  4  5  4  1  6 18  9  8
#   8 11  9  7  7  7  4  3  7  7  8  7  3  9  5 10  7  5 10  5  2 10  5  6
#   5 10  8  5  5  7  4 12  9  5  4  5  5  4  8  8  6 11 10  7 10  6  9  7
#   2  6  7  9  8  5  6  7  6  2  9  8  8  7  6  9  5  2  4  9  9  5  6 10
#   4  9  8  6  4  7  4  8  5  6  7  7  5  8  6 10  9 11  6  6  4  6  6  6
#   4  4  5  5  7  9 10  8  5  4  9  8  7  5  9  4  6  7  5  5  5  9  7  6
#   9  5  7  6  8  6  5  3  5  6 10  6 10 10  3  4]

# %% [markdown]
# # <font color="orange">PDF(Continuous) - PMF(discrete) - CDF</font>

# %%
DT_binomial = stats.binom(5000,.2)
TAKHT = 400
pmfsum = 0
# for i in range(1000, 5000):
#     pmfsum+= DT_binomial.pmf(i)
# print(pmfsum)
DT_binomial.cdf(5000) - DT_binomial.cdf(1000)
# Out:
# 0.49153823516345097

# %%
DT_poisson = stats.poisson(160) #160 moshtari dar rooz
1 - DT_poisson.cdf(150) # ehtemal 200 moshtari be bala da rooz
# Out:
# 0.7719677058307436

# %% [markdown]
# # <font color="orange">Comparison Distributions</font>
#  * Kullback Divergence (KL)
#  * Jenson Shanon(JS)
#  * Kolmogorov Smirnov (KS)

# %%
def KL_divergence(p,q):
    return np.sum(
        np.where(np.logical_and(p!=0,q!=0), p* np.log(p/q), 0 )
    )

# %%
DT_X = np.arange(-10,10,0.001)
p = stats.norm.pdf(DT_X,0,2) / len(DT_X)
q = stats.norm.pdf(DT_X,2,3)/ len(DT_X)

PLT.plot(DT_X,p)
PLT.plot(DT_X,q, c='red')
KL_divergence(p,q)
# Out:
# 0.017495674168934057

# %% [markdown]
# ### <font color="Brown">Kullback Divergence (KL)</font>

# %%
WH = pd.read_csv('../datasets/weight-height.csv')
WH.head()
# Out:
#   Gender     Height      Weight
# 0   Male  73.847017  241.893563
# 1   Male  68.781904  162.310473
# 2   Male  74.110105  212.740856
# 3   Male  71.730978  220.042470
# 4   Male  69.881796  206.349801

# %%
MH = WH[WH['Gender']=='Male']['Height']
FMH = WH[WH['Gender']=='Female']['Height']

NMH = stats.norm.rvs(size=len(MH), loc=MH.mean(), scale=MH.std())
PLT.hist(NMH,bins=100)
PLT.hist(MH,bins=100)
# Out:
# (array([  1.,   0.,   0.,   0.,   1.,   0.,   0.,   3.,   2.,   3.,   1.,
#           5.,   5.,   4.,   6.,   5.,   8.,   9.,   9.,  12.,  14.,   9.,
#          16.,  16.,  19.,  29.,  34.,  27.,  20.,  37.,  47.,  56.,  60.,
#          63.,  59.,  70.,  77.,  78.,  88.,  89.,  96., 101., 125., 131.,
#         127., 129., 148., 148., 150., 135., 122., 168., 145., 139., 151.,
#         134., 124., 112., 144.,  93., 133., 109.,  98., 115., 113., 103.,
#          83.,  79.,  62.,  61.,  46.,  50.,  40.,  43.,  42.,  34.,  28.,
#          30.,  16.,  20.,  13.,  11.,   8.,  11.,   5.,   8.,   4.,   7.,
#           8.,   4.,   3.,   1.,   3.,   0.,   0.,   1.,   0.,   2.,   1.,
#           1.]),
#  array([58.40690493, 58.61282331, 58.81874168, 59.02466005, 59.23057843,
#         59.4364968 , 59.64241518, 59.84833355, 60.05425192, 60.2601703 ,
#         60.46608867, 60.67200705, 60.87792542, 61.0838438 , 61.28976217,
#         61.49568054, 61.70159892, 61.90751729, 62.11343567, 62.31935404,
#         62.52527241, 62.73119079, 62.93710916, 63.14302754, 63.34894591,
#         63.55486429, 63.76078266, 63.96670103, 64.17261941, 64.37853778,
#         64.58445616, 64.79037453, 64.9962929 , 65.20221128, 65.40812965,
#         65.61404803, 65.8199664 , 66.02588478, 66.23180315, 66.43772152,
#         66.6436399 , 66.84955827, 67.05547665, 67.26139502, 67.46731339,
#         67.67323177, 67.87915014, 68.08506852, 68.29098689, 68.49690526,
#         68.70282364, 68.90874201, 69.11466039, 69.32057876, 69.52649714,
#         69.73241551, 69.93833388, 70.14425226, 70.35017063, 70.55608901,
#         70.76200738, 70.96792575, 71.17384413, 71.3797625 , 71.58568088,
#         71.79159925, 71.99751763, 72.203436  , 72.40935437, 72.61527275,
#         72.82119112, 73.0271095 , 73.23302787, 73.43894624, 73.64486462,
#         73.85078299, 74.05670137, 74.26261974, 74.46853812, 74.67445649,
#         74.88037486, 75.08629324, 75.29221161, 75.49812999, 75.70404836,
#         75.90996673, 76.11588511, 76.32180348, 76.52772186, 76.73364023,
#         76.9395586 , 77.14547698, 77.35139535, 77.55731373, 77.7632321 ,
#         77.96915048, 78.17506885, 78.38098722, 78.5869056 , 78.79282397,
#         78.99874235]),
#  <BarContainer object of 100 artists>)

# %%
MHcount, _ = np.histogram(MH,bins=100)
FMHcount, _ = np.histogram(FMH,bins=100)
NMHcount, _ = np.histogram(NMH,bins=100)
KL_divergence(MHcount/len(MH),NMHcount/len(MH))
# Out:
# /tmp/ipykernel_1050/2900689964.py:3: RuntimeWarning: divide by zero encountered in true_divide
#   np.where(np.logical_and(p!=0,q!=0), p* np.log(p/q), 0 )
# /tmp/ipykernel_1050/2900689964.py:3: RuntimeWarning: invalid value encountered in true_divide
#   np.where(np.logical_and(p!=0,q!=0), p* np.log(p/q), 0 )
# /tmp/ipykernel_1050/2900689964.py:3: RuntimeWarning: divide by zero encountered in log
#   np.where(np.logical_and(p!=0,q!=0), p* np.log(p/q), 0 )
# /tmp/ipykernel_1050/2900689964.py:3: RuntimeWarning: invalid value encountered in multiply
#   np.where(np.logical_and(p!=0,q!=0), p* np.log(p/q), 0 )
# 0.02272769287266869

# %%
PLT.plot(MHcount)
PLT.plot(NMHcount,c='red')

# %% [markdown]
# ### <font color="Brown">Jenson Shanon(JS): 0~ JS ~1 sensitive to bins</font>

# %%
def Jenson_shanon(p,q):
    p = p / np.linalg.norm(p, ord=1)
    q = q / np.linalg.norm(q, ord=1)
    m = .5 * (p + q)
    return  .5 * ( stats.entropy(p,m) + stats.entropy(q,m) )

# %%
Jenson_shanon(MHcount,NMHcount) # MH is a normal distribution
# Out:
# 0.00693403876205628

# %%
WINSPEED = pd.read_csv('../datasets/wind_speed_laurel_nebraska.csv')
WINSPEED.head()
# Out:
#    10 Min Std Dev              Time  10 Min Sampled Avg
# 0            2.73  2001-06-11 11:00                22.3
# 1            1.98  2001-06-11 11:10                23.0
# 2            1.87  2001-06-11 11:20                23.3
# 3            2.03  2001-06-11 11:30                22.0
# 4            3.10  2001-06-11 11:40                20.5

# %%
NWINSPEED_AVG = stats.norm.rvs(size=len(WINSPEED['10 Min Sampled Avg']), loc=WINSPEED['10 Min Sampled Avg'].mean(), scale=WINSPEED['10 Min Sampled Avg'].std() )
WINSPEED_AVG_count, _ = np.histogram(WINSPEED['10 Min Sampled Avg'], bins=100)
NWINSPEED_AVG_count, _ = np.histogram(NWINSPEED_AVG, bins=100)

# %%
Jenson_shanon(WINSPEED_AVG_count,NWINSPEED_AVG_count)
# Out:
# 0.14969229202499362

# %%
PLT.hist(WINSPEED['10 Min Sampled Avg'], bins=20)
PLT.hist(NWINSPEED_AVG, bins=20)
# Out:
# (array([ 1.,  2.,  4.,  7.,  7., 12., 18., 20., 22., 20., 30., 17., 20.,
#         15., 10.,  8.,  2.,  3.,  1.,  2.]),
#  array([ 3.53779921,  5.15935569,  6.78091216,  8.40246864, 10.02402512,
#         11.64558159, 13.26713807, 14.88869454, 16.51025102, 18.1318075 ,
#         19.75336397, 21.37492045, 22.99647692, 24.6180334 , 26.23958988,
#         27.86114635, 29.48270283, 31.1042593 , 32.72581578, 34.34737226,
#         35.96892873]),
#  <BarContainer object of 20 artists>)

# %% [markdown]
# ### <font color="Brown">Kolmogorov Smirnov (KS)</font>
#  * H0 : two distribution is same
#  * if p-value under 0.05 reject H0

# %%
PLT.hist(MH)
PLT.hist(NMH)
PLT.show()

PLT.plot(np.cumsum(MHcount))
PLT.plot(np.cumsum(NMHcount))
PLT.show()

stats.kstest(MHcount, NMHcount)
# Out:
# KstestResult(statistic=0.05, pvalue=0.9996892272702655)

# %%
PLT.hist(MH.sort_values().reset_index(drop=True),bins=100)
PLT.hist(FMH.sort_values().reset_index(drop=True),bins=100)
PLT.show()

PLT.plot(MH.sort_values().reset_index(drop=True))
PLT.plot(FMH.sort_values().reset_index(drop=True))
PLT.show()

stats.kstest(MH, FMH)
# Out:
# KstestResult(statistic=0.6664, pvalue=0.0)

# %%
PLT.hist(np.cumsum(MH.sort_values().reset_index(drop=True)),bins=100)
PLT.hist(np.cumsum(FMH.sort_values().reset_index(drop=True)),bins=100)
PLT.show()

PLT.plot(np.cumsum(MH.sort_values().reset_index(drop=True)))
PLT.plot(np.cumsum(FMH.sort_values().reset_index(drop=True)))
PLT.show()

# %%
stats.kstest(np.cumsum(MHcount), np.cumsum(FMHcount), N=1000)
# Out:
# KstestResult(statistic=0.04, pvalue=0.999998821968263)

# %%
# zero center
PLT.hist(MH-MH.mean(),bins=100)
PLT.hist(FMH-FMH.mean(),bins=100)
# Out:
# (array([  1.,   1.,   0.,   1.,   1.,   1.,   0.,   3.,   2.,   7.,   0.,
#           4.,   4.,   8.,   8.,  11.,   7.,   9.,  16.,  12.,  17.,  20.,
#          28.,  24.,  30.,  26.,  37.,  37.,  45.,  49.,  71.,  48.,  68.,
#          92.,  89.,  77.,  92.,  97., 108., 111., 127., 129., 115., 135.,
#         146., 130., 135., 133., 124., 152., 148., 130., 131., 142., 138.,
#         120., 129., 123.,  97., 108.,  93.,  93., 116.,  91.,  83.,  72.,
#          64.,  65.,  64.,  43.,  47.,  43.,  42.,  34.,  18.,  27.,  21.,
#          21.,  21.,  17.,  11.,  11.,   9.,   5.,   9.,  10.,   4.,   3.,
#           2.,   1.,   1.,   0.,   1.,   1.,   2.,   0.,   0.,   0.,   0.,
#           1.]),
#  array([-9.44564028, -9.25437575, -9.06311123, -8.8718467 , -8.68058218,
#         -8.48931765, -8.29805313, -8.1067886 , -7.91552408, -7.72425955,
#         -7.53299502, -7.3417305 , -7.15046597, -6.95920145, -6.76793692,
#         -6.5766724 , -6.38540787, -6.19414335, -6.00287882, -5.8116143 ,
#         -5.62034977, -5.42908524, -5.23782072, -5.04655619, -4.85529167,
#         -4.66402714, -4.47276262, -4.28149809, -4.09023357, -3.89896904,
#         -3.70770452, -3.51643999, -3.32517547, -3.13391094, -2.94264641,
#         -2.75138189, -2.56011736, -2.36885284, -2.17758831, -1.98632379,
#         -1.79505926, -1.60379474, -1.41253021, -1.22126569, -1.03000116,
#         -0.83873663, -0.64747211, -0.45620758, -0.26494306, -0.07367853,
#          0.11758599,  0.30885052,  0.50011504,  0.69137957,  0.88264409,
#          1.07390862,  1.26517314,  1.45643767,  1.6477022 ,  1.83896672,
#          2.03023125,  2.22149577,  2.4127603 ,  2.60402482,  2.79528935,
#          2.98655387,  3.1778184 ,  3.36908292,  3.56034745,  3.75161197,
#          3.9428765 ,  4.13414103,  4.32540555,  4.51667008,  4.7079346 ,
#          4.89919913,  5.09046365,  5.28172818,  5.4729927 ,  5.66425723,
#          5.85552175,  6.04678628,  6.23805081,  6.42931533,  6.62057986,
#          6.81184438,  7.00310891,  7.19437343,  7.38563796,  7.57690248,
#          7.76816701,  7.95943153,  8.15069606,  8.34196058,  8.53322511,
#          8.72448964,  8.91575416,  9.10701869,  9.29828321,  9.48954774,
#          9.68081226]),
#  <BarContainer object of 100 artists>)

# %%
stats.kstest(MH-MH.mean(), FMH-FMH.mean())
# Out:
# KstestResult(statistic=0.0194, pvalue=0.3035775745288207)

# %%
stats.kstest(MH-MH.mean(),'norm')
# Out:
# KstestResult(statistic=0.23808525858975527, pvalue=7.336270444149125e-250)

# %%
stats.kstest(MH,NMH)
# Out:
# KstestResult(statistic=0.018, pvalue=0.3927625063294053)

# %% [markdown]
# # <font color="orange">AB Testing</font>

# %%
A = np.array([23,21,19,24,35,17,18,24,33,21,23,27])
B = np.array([31,28,19,24,32,27,16,41,23,32,29,33])

# %%
print(A.mean())
print(B.mean())
print(B.mean()-A.mean())

print(A.std())
print(B.std())
# Out:
# 23.75
# 27.916666666666668
# 4.166666666666668
# 5.324863065531983
# 6.473771869800651

# %%
def suffle_experiment(A,B,N):
    ABAPEND = np.append(A,B)
    np.random.shuffle(ABAPEND)
    
    diff_mean = np.empty([N,1])
    for _ in range(N):
        EXLABEL = np.random.randint(0,2, len(ABAPEND))
        EXDATA = np.array([EXLABEL,ABAPEND]).T
        EXA = EXDATA[EXDATA[:,0]==0]
        EXB = EXDATA[EXDATA[:,0]==1]
        diff_mean[_] = EXB[:,1].mean() - EXA[:,1].mean()
    return diff_mean

# %%
RLDIFF = B.mean() - A.mean()
EXDIFF = suffle_experiment(A,B,1000)
len(EXDIFF[EXDIFF>=RLDIFF]) / len(EXDIFF)
# Out:
# 0.06

# %%
SB.displot(EXDIFF, kde=True)

# %% [markdown]
# ### <font color="Brown">AB Test (sales real data): </font>

# %%
ABDATA = pd.read_csv('../datasets/ab_data.csv', usecols=['user_id','group','landing_page','converted','timestamp'])
display(ABDATA.head())
# Out:
#    user_id                   timestamp      group landing_page  converted
# 0   851104  2017-01-21 22:11:48.556739    control     old_page          0
# 1   804228  2017-01-12 08:01:45.159739    control     old_page          0
# 2   661590  2017-01-11 16:55:06.154213  treatment     new_page          0
# 3   853541  2017-01-08 18:28:03.143765  treatment     new_page          0
# 4   864975  2017-01-21 01:52:26.210827    control     old_page          1

# %%
print(ABDATA.shape)
ABDATA.nunique()
# Out:
# (294478, 5)
# user_id         290584
# timestamp       294478
# group                2
# landing_page         2
# converted            2
# dtype: int64

# %%
A_CONDITION = (ABDATA['group']=='control') & (ABDATA['landing_page']=='old_page') 
B_CONDITION = (ABDATA['group']=='treatment') & (ABDATA['landing_page']=='new_page')
# ABDATA = ABDATA[A_CONDITION | B_CONDITION]
ADATA = ABDATA[A_CONDITION]
BDATA = ABDATA[B_CONDITION]
ABDATA = ADATA.merge(BDATA, how='outer')

ABDATA.drop_duplicates('user_id',inplace=True)
# ABDATA[ABDATA['user_id'].duplicated()]
# ABDATA.drop(ABDATA[ABDATA['user_id'].duplicated()].index,inplace=True)

len(ABDATA)
# Out:
# 290584

# %%
ABDATA['converted'].describe()[['count','mean']]
# Out:
# count    290584.000000
# mean          0.119597
# Name: converted, dtype: float64

# %%
ADATA['converted'].describe()[['count','mean']]
# Out:
# count    145274.000000
# mean          0.120386
# Name: converted, dtype: float64

# %%
BDATA['converted'].describe()[['count','mean']]
# Out:
# count    145311.000000
# mean          0.118807
# Name: converted, dtype: float64

# %%
ABDATA[~ABDATA['user_id'].duplicated()]
# Out:
#         user_id                   timestamp      group landing_page  converted
# 0        851104  2017-01-21 22:11:48.556739    control     old_page          0
# 1        804228  2017-01-12 08:01:45.159739    control     old_page          0
# 2        864975  2017-01-21 01:52:26.210827    control     old_page          1
# 3        936923  2017-01-10 15:20:49.083499    control     old_page          0
# 4        719014  2017-01-17 01:48:29.539573    control     old_page          0
# ...         ...                         ...        ...          ...        ...
# 290580   677163  2017-01-03 19:41:51.902148  treatment     new_page          0
# 290581   925675  2017-01-07 20:38:26.346410  treatment     new_page          0
# 290582   643562  2017-01-02 19:20:05.460595  treatment     new_page          0
# 290583   822004  2017-01-04 03:36:46.071379  treatment     new_page          0
# 290584   715931  2017-01-16 12:40:24.467417  treatment     new_page          0
#
# [290584 rows x 5 columns]

# %%
# H0: m1 = m2
# H1: m2 < m1

# %%
ADATA_sample_converted = np.random.choice(
    [1,0], size=len(ADATA), p=[ABDATA['converted'].mean(),(1-ABDATA['converted'].mean())]
)

BDATA_sample_converted = np.random.choice(
    [1,0], size=len(BDATA), p=[ABDATA['converted'].mean(),(1-ABDATA['converted'].mean())]
)

print(ADATA_sample_converted.mean())
print(BDATA_sample_converted.mean())
# Out:
# 0.11942949185676721
# 0.11931650047140271

# %%
ADATA_sample_converted = stats.binom.rvs(size=10000, p=ABDATA['converted'].mean(),n=len(ADATA))
ADATA_sample_converted = ADATA_sample_converted/len(ADATA)

BDATA_sample_converted = stats.binom.rvs(size=10000, p=ABDATA['converted'].mean(),n=len(BDATA))
BDATA_sample_converted = BDATA_sample_converted/len(BDATA)

ABDATA_sample_diff = ADATA_sample_converted - BDATA_sample_converted
ABDATA_diff_mean = ADATA['converted'].mean() - BDATA['converted'].mean()

(ABDATA_sample_diff > ABDATA_diff_mean).mean() #===> result > 0.05 ==> bar asas shance boode
# Out:
# 0.0969

# %%
PLT.hist(ABDATA_sample_diff,bins=100)
PLT.axvline(x=ABDATA_diff_mean, c='g')
PLT.axvline(x=ABDATA_sample_diff.mean(), c='r')
PLT.show()

# %%
sum(ADATA['converted'])
# Out:
# 17489

# %%
SM.stats.proportions_ztest(
    [sum(ADATA['converted']),sum(BDATA['converted'])], [len(ADATA['converted']),len(BDATA['converted'])]
)
# Out:
# (1.3116075339133115, 0.18965258971881804)

# %%
SM.stats.proportions_ztest(
    [sum(ADATA['converted']),sum(BDATA['converted'])], [len(ADATA['converted']),len(BDATA['converted'])],
    alternative='smaller'
)
# Out:
# (1.3116075339133115, 0.905173705140591)

# %%
SM.stats.proportions_ztest(
    [sum(ADATA['converted']),sum(BDATA['converted'])], [len(ADATA['converted']),len(BDATA['converted'])],
    alternative='larger'
)
# Out:
# (1.3116075339133115, 0.09482629485940902)

# %% [markdown]
# ### <font color="Brown">degree of freedom (DF) And F-Distributions: </font>

# %%
DF1 = 4
DF2 = 80
FDATA = stats.f.rvs(DF1,DF2,size=10000)

# %%
PLT.hist(FDATA, bins=100)
PLT.show()

# %% [markdown]
# ### <font color="Brown">Chi-2 (chi-squre) Distribution: </font>

# %%
df = 10
CHIDATA = stats.chi2.rvs(df, size=1000)

# %%
PLT.hist(CHIDATA, bins=50)
PLT.show()

# %% [markdown]
# ### <font color="Brown">AB Test (corona): </font>

# %%
CNDATA = pd.read_csv('../datasets/Corona_Updated.csv')
display(CNDATA.head())
CNDATA.shape
# Out:
#   Province/State              Country/Region          Last Update  Confirmed  \
# 0          Hubei              Mainland China  2020-03-10T15:13:05      67760
# 1            NaN                       Italy  2020-03-10T17:53:02      10149
# 2            NaN  Iran (Islamic Republic of)  2020-03-10T19:13:20       8042
# 3            NaN           Republic of Korea  2020-03-10T19:13:20       7513
# 4            NaN                      France  2020-03-10T18:53:02       1784
#
#    Deaths  Recovered  Latitude  Longitude  Temprature  Humidity  Temp_Cat  \
# 0    3024      47743   30.9756   112.2707        12.5        86         1
# 1     631        724   43.0000    12.0000        12.9        64         1
# 2     291       2731   32.0000    53.0000        11.9         9         0
# 3      54        247   36.0000   128.0000         4.9        41         0
# 4      33         12   47.0000     2.0000        11.9        93         0
#
#    Humid_Cat
# 0          1
# 1          1
# 2          0
# 3          0
# 4          0
# (206, 12)

# %%
CNDATA['Temp_Cat'] = CNDATA['Temprature'].apply(lambda i : 0 if i<24 else 1)

# %%
ADATA = CNDATA[CNDATA['Temp_Cat']==1]['Confirmed']
BDATA = CNDATA[CNDATA['Temp_Cat']==0]['Confirmed']

# %%
ADATA.describe()[['mean','std']]
# Out:
# mean    26.548387
# std     45.939699
# Name: Confirmed, dtype: float64

# %%
BDATA.describe()[['mean','std']]
# Out:
# mean     672.908571
# std     5228.628798
# Name: Confirmed, dtype: float64

# %%
z = (
        (ADATA.mean() - BDATA.mean())  
        /
        np.sqrt(
        (ADATA.std()**2/len(ADATA)) +
        (BDATA.std()**2/len(BDATA))
        )
    )
z
# Out:
# -1.6349753148440753

# %%
pvalue = 2 * (1 - stats.norm.cdf(np.abs(z)))
pvalue
# Out:
# 0.10205422251419871

# %% [markdown]
# ### <font color="Brown">ANOVA (analaysis of variance) - multi group test ABC... - use F distribution: </font>

# %%
CPDATA = pd.read_csv('../datasets/3campain.csv')
CPDATA.head()
# Out:
#   Campain  Sell
# 0       A  12.6
# 1       A  12.0
# 2       A  11.8
# 3       A  11.9
# 4       A  13.0

# %%
CPDATA.groupby('Campain').describe()
# Out:
#          Sell
#         count       mean       std   min    25%    50%    75%   max
# Campain
# A         7.0  12.542857  0.774289  11.8  11.95  12.50  12.80  14.0
# B         6.0  11.533333  1.728198  10.0  10.05  11.10  12.75  14.0
# C         8.0  11.825000  1.731845   8.9  10.55  12.45  13.10  13.6

# %%
from statsmodels.formula.api import ols

# %%
OLS_RESULT = ols('Sell ~ Campain', data=CPDATA).fit()

# %%
SM.stats.anova_lm(OLS_RESULT)
# Out:
#             df     sum_sq   mean_sq         F    PR(>F)
# Campain    2.0   3.606905  1.803452  0.821297  0.455683
# Residual  18.0  39.525476  2.195860       NaN       NaN
