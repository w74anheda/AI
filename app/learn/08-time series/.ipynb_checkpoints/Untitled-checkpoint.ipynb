# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as PLT
import seaborn as SB
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.statespace.sarimax import SARIMAX

# %%
DF = pd.read_csv('../../datasets/BTC-USD.csv',usecols=['Date','Adj Close']).rename(columns={'Date':'date','Adj Close':'price'})

# %%
DF['date'] = pd.to_datetime(DF['date'])

# %%
GRPS = DF.resample(rule='W', on='date')['price'].mean()
DFM = pd.concat([pd.Series(GRPS.keys()),pd.Series(GRPS.values,name='price')],axis=1)

GRPS = DF.resample(rule='Y', on='date')['price'].mean()
DFY = pd.concat([pd.Series(GRPS.keys()),pd.Series(GRPS.values,name='price')],axis=1)

# %% [markdown]
# # sarimax (data must be Stationarity)
#
# ### Stationarity:
# #### A stationary time series is one whose properties do not depend on the time at which the series is observed

# %%
PLT.figure(figsize=(20,5))
PLT.plot(DFM['date'],DFM['price'])
# PLT.plot(DFY['date'],DFY['price'])

# %%
# AdFuller = adfuller(DFM['price'])[1]
# isStationarity = AdFuller < .05

# if isStationarity:
#     DFM['price'] = np.log(DFM['price'])
# AdFuller

# %%
# PLT.figure(figsize=(20,5))
# PLT.plot(DFM['date'],DFM['price'])

# %%
# for i in range(0,6):
#     DFM['price'] = DFM['price'].diff() #differentiate
#     DFM.dropna(inplace=True)

# %%
# AdFuller = adfuller(DFM['price'])[1]
# AdFuller

# %%
# PLT.figure(figsize=(20,5))
# PLT.plot(DFM['date'],DFM['price'])

# %%
AR = 10 # count of look past data
I = 1 # diff
MA = 10 # count of look past noise data
# model = SARIMAX(DFM['price'],order=(AR,I,MA)) #,seasonal_order=(3,1,3,  4)
model = SARIMAX(DFM['price'],order=(3, 5, 3)) #,seasonal_order=(3,1,3,  4)
result = model.fit()
# Out:
# /opt/conda/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            7     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.10539D+01    |proj g|=  4.44161D+00
#
# At iterate    5    f=  9.58468D+00    |proj g|=  1.72768D-01
#
# At iterate   10    f=  9.35194D+00    |proj g|=  5.21394D-02
#
# At iterate   15    f=  9.31670D+00    |proj g|=  9.32729D-03
#
# At iterate   20    f=  9.20950D+00    |proj g|=  2.11111D-02
#
# At iterate   25    f=  9.19370D+00    |proj g|=  3.72502D-02
#
# At iterate   30    f=  9.19048D+00    |proj g|=  3.07914D-04
#
# At iterate   35    f=  9.19024D+00    |proj g|=  4.57474D-03
#
# At iterate   40    f=  9.18971D+00    |proj g|=  4.91042D-04
#
# At iterate   45    f=  9.18966D+00    |proj g|=  1.32861D-03
#
# At iterate   50    f=  9.18962D+00    |proj g|=  1.15516D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     7     50     68      1     0     0   1.155D-03   9.190D+00
#   F =   9.1896188314450953
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# /opt/conda/lib/python3.9/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  price   No. Observations:                  184
# Model:               SARIMAX(3, 5, 3)   Log Likelihood               -1690.890
# Date:                Wed, 16 Nov 2022   AIC                           3395.780
# Time:                        14:42:33   BIC                           3418.091
# Sample:                             0   HQIC                          3404.827
#                                 - 184
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.4654      0.137     -3.409      0.001      -0.733      -0.198
# ar.L2         -0.4233      0.144     -2.944      0.003      -0.705      -0.141
# ar.L3         -0.3278      0.125     -2.621      0.009      -0.573      -0.083
# ma.L1         -2.8737      0.147    -19.494      0.000      -3.163      -2.585
# ma.L2          2.8070      0.292      9.600      0.000       2.234       3.380
# ma.L3         -0.9320      0.151     -6.186      0.000      -1.227      -0.637
# sigma2      1.777e+07    2.5e-08    7.1e+14      0.000    1.78e+07    1.78e+07
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.29   Jarque-Bera (JB):               152.04
# Prob(Q):                              0.59   Prob(JB):                         0.00
# Heteroskedasticity (H):               6.30   Skew:                            -0.03
# Prob(H) (two-sided):                  0.00   Kurtosis:                         7.51
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 1.78e+30. Standard errors may be unstable.
# """

# %%
DFM['sarimax'] = result.fittedvalues

# %%
PLT.figure(figsize=(20,5))
PLT.plot(DFM['date'],DFM['price'])
PLT.plot(DFM['date'],DFM['sarimax'])

# %%
predicted = result.predict(start=len(DFM),end=len(DFM)+5)
predicted = DFM['sarimax'].append(predicted)
# Out:
# /tmp/ipykernel_9896/2076923715.py:2: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   predicted = DFM['sarimax'].append(predicted)

# %%
PLT.figure(figsize=(20,10))
PLT.plot(DFM['price'])
PLT.plot(predicted)

# %%
# custom grid search
from itertools import product
p = range(0,5,1)
d = range(5,8)
q = range(0,5,1)
params = list(product(p,d,q))
len(list(params))
# Out:
# 75

# %%
aies = []
for i,order in enumerate(params):
    print(f'****************************************{i}********************************************')
    print(f'****************************************{i}********************************************')
    print(f'****************************************{i}********************************************')
    print(f'****************************************{i}********************************************')

    try:
        model = SARIMAX(DF['price'],order=order)
        response = model.fit()
        aies.append((response.aic,order))
    except:
        continue
# Out:
# ****************************************0********************************************
# ****************************************0********************************************
# ****************************************0********************************************
# ****************************************0********************************************
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            1     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.03325D+01    |proj g|=  9.21574D-07
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     1      0      1      0     0     0   9.216D-07   1.033D+01
#   F =   10.332473969417856
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ****************************************1********************************************
# ****************************************1********************************************
# ****************************************1********************************************
# ****************************************1********************************************
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.05633D+01    |proj g|=  1.87357D+00
#
# At iterate    5    f=  9.76787D+00    |proj g|=  1.97551D-02
#  This problem is unconstrained.
# /opt/conda/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
#  This problem is unconstrained.
# At iterate   10    f=  9.74632D+00    |proj g|=  9.47288D-04
#
# At iterate   15    f=  9.74331D+00    |proj g|=  6.67129D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2     18     20      1     0     0   7.958D-06   9.703D+00
#   F =   9.7030689393097305
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ****************************************2********************************************
# ****************************************2********************************************
# ****************************************2********************************************
# ****************************************2********************************************
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.08757D+01    |proj g|=  2.67760D+00
# /opt/conda/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
#  This problem is unconstrained.
# At iterate    5    f=  9.42676D+00    |proj g|=  2.87844D-02
#
# At iterate   10    f=  9.38487D+00    |proj g|=  1.41917D-03
#
# At iterate   15    f=  9.37867D+00    |proj g|=  1.64989D-04
#  Warning:  more than 10 function and gradient
#    evaluations in the last line search.  Termination
#    may possibly be caused by a bad search direction.
# /opt/conda/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
#  This problem is unconstrained.
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     18     37      1     0     0   6.519D-05   9.096D+00
#   F =   9.0961145448161300
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# ****************************************3********************************************
# ****************************************3********************************************
# ****************************************3********************************************
# ****************************************3********************************************
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.28040D+01    |proj g|=  6.57480D+00
#
# At iterate    5    f=  9.03989D+00    |proj g|=  6.01598D-02
#
# At iterate   10    f=  8.91733D+00    |proj g|=  1.48817D-03
#
# At iterate   15    f=  8.91415D+00    |proj g|=  6.15694D-03
#  Bad direction in the line search;
#    refresh the lbfgs memory and restart the iteration.
#
#  Warning:  more than 10 function and gradient
#    evaluations in the last line search.  Termination
#    may possibly be caused by a bad search direction.
#  This problem is unconstrained.
# /opt/conda/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
#  This problem is unconstrained.
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     18     60      2     0     0   4.302D-04   8.780D+00
#   F =   8.7798952639476315
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# ****************************************4********************************************
# ****************************************4********************************************
# ****************************************4********************************************
# ****************************************4********************************************
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            1     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.09676D+01    |proj g|=  5.36815D-07
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     1      0      1      0     0     0   5.368D-07   1.097D+01
#   F =   10.967646691123219
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ****************************************5********************************************
# ****************************************5********************************************
# ****************************************5********************************************
# ****************************************5********************************************
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.11178D+01    |proj g|=  1.68155D+00
#
# At iterate    5    f=  1.04214D+01    |proj g|=  1.70141D-02
#
# At iterate   10    f=  1.04030D+01    |proj g|=  8.11431D-04
#
# At iterate   15    f=  1.04009D+01    |proj g|=  4.17872D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2     18     22      1     0     0   6.631D-06   1.033D+01
#   F =   10.327466689201570
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ****************************************6********************************************
# ****************************************6********************************************
# ****************************************6********************************************
# ****************************************6********************************************
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.12895D+01    |proj g|=  2.20032D+00
# /opt/conda/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
#  This problem is unconstrained.
# At iterate    5    f=  1.01301D+01    |proj g|=  2.24016D-02
#
# At iterate   10    f=  1.00990D+01    |proj g|=  9.94858D-04
#
# At iterate   15    f=  1.00958D+01    |proj g|=  8.42434D-05
#
# At iterate   20    f=  9.70117D+00    |proj g|=  1.58362D-06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     20     36      1     0     0   1.584D-06   9.701D+00
#   F =   9.7011682178140628
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ****************************************7********************************************
# ****************************************7********************************************
# ****************************************7********************************************
# ****************************************7********************************************
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.37076D+01    |proj g|=  7.32371D+00
# /opt/conda/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
#  This problem is unconstrained.
# At iterate    5    f=  9.60352D+00    |proj g|=  6.01829D-02
#
# At iterate   10    f=  9.50675D+00    |proj g|=  2.39789D-03
#
# At iterate   15    f=  9.49820D+00    |proj g|=  1.26107D-04
#
# At iterate   20    f=  9.47771D+00    |proj g|=  1.00705D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     23     41      1     0     0   4.079D-04   9.209D+00
#   F =   9.2086769006362523
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# ****************************************8********************************************
# ****************************************8********************************************
# ****************************************8********************************************
# ****************************************8********************************************
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            1     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.16096D+01    |proj g|=  3.04823D-07
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     1      0      1      0     0     0   3.048D-07   1.161D+01
#   F =   11.609622548685575
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ****************************************9********************************************
# ****************************************9********************************************
# ****************************************9********************************************
# ****************************************9********************************************
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.17067D+01    |proj g|=  1.52524D+00
#  This problem is unconstrained.
# /opt/conda/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
#  This problem is unconstrained.
# At iterate    5    f=  1.10866D+01    |proj g|=  1.49738D-02
#
# At iterate   10    f=  1.10705D+01    |proj g|=  7.10140D-04
#
# At iterate   15    f=  1.10689D+01    |proj g|=  2.36231D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2     18     23      1     0     0   3.303D-06   1.096D+01
#   F =   10.961854046081626
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ****************************************10********************************************
# ****************************************10********************************************
# ****************************************10********************************************
# ****************************************10********************************************
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.17993D+01    |proj g|=  1.85666D+00
# /opt/conda/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
#  This problem is unconstrained.
# At iterate    5    f=  1.08405D+01    |proj g|=  1.79538D-02
#
# At iterate   10    f=  1.08159D+01    |proj g|=  7.86597D-04
#
# At iterate   15    f=  1.08139D+01    |proj g|=  4.18128D-05
#
# At iterate   20    f=  1.07916D+01    |proj g|=  8.78076D-03
#
# At iterate   25    f=  1.03547D+01    |proj g|=  2.40039D-02
#
# At iterate   30    f=  1.03285D+01    |proj g|=  2.83807D-04
#  Warning:  more than 10 function and gradient
#    evaluations in the last line search.  Termination
#    may possibly be caused by a bad search direction.
# /opt/conda/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
#  This problem is unconstrained.
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     31     61      1     0     0   2.816D-04   1.033D+01
#   F =   10.328477432062895
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# ****************************************11********************************************
# ****************************************11********************************************
# ****************************************11********************************************
# ****************************************11********************************************
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.35626D+01    |proj g|=  5.93322D+00
#
# At iterate    5    f=  1.03061D+01    |proj g|=  4.95131D-02
#
# At iterate   10    f=  1.02374D+01    |proj g|=  2.25616D-03
#
# At iterate   15    f=  1.02310D+01    |proj g|=  7.57515D-05
#
# At iterate   20    f=  1.02300D+01    |proj g|=  1.17764D-04
#
# At iterate   25    f=  1.02256D+01    |proj g|=  1.13157D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     25     45      1     0     0   1.132D-03   1.023D+01
#   F =   10.225622875021259
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# ****************************************12********************************************
# ****************************************12********************************************
# ****************************************12********************************************
# ****************************************12********************************************
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  9.77355D+00    |proj g|=  8.88322D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      2      4      1     0     0   2.133D-06   9.774D+00
#   F =   9.7735499229047793
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
#  Warning:  more than 10 function and gradient
#    evaluations in the last line search.  Termination
#    may possibly be caused by a bad search direction.
#  This problem is unconstrained.
# ****************************************13********************************************
# ****************************************13********************************************
# ****************************************13********************************************
# ****************************************13********************************************
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.02741D+01    |proj g|=  1.90611D+00
#
# At iterate    5    f=  9.27538D+00    |proj g|=  2.77016D-02
# /opt/conda/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
#  This problem is unconstrained.
# At iterate   10    f=  9.24601D+00    |proj g|=  4.44286D-03
#
# At iterate   15    f=  9.24170D+00    |proj g|=  1.81476D-04
#
# At iterate   20    f=  9.24136D+00    |proj g|=  1.89980D-04
#
# At iterate   25    f=  9.23920D+00    |proj g|=  7.51267D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     29     32      1     0     0   1.567D-06   9.238D+00
#   F =   9.2381446142829056
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ****************************************14********************************************
# ****************************************14********************************************
# ****************************************14********************************************
# ****************************************14********************************************
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.03883D+01    |proj g|=  2.13622D+00
# /opt/conda/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
#  This problem is unconstrained.
# At iterate    5    f=  8.99261D+00    |proj g|=  2.52738D-02
#
# At iterate   10    f=  8.95204D+00    |proj g|=  3.09390D-03
#
# At iterate   15    f=  8.94535D+00    |proj g|=  2.36866D-04
#
# At iterate   20    f=  8.75755D+00    |proj g|=  1.65104D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     24     51      1     0     0   1.345D-02   8.749D+00
#   F =   8.7487953049212539
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# ****************************************15********************************************
# ****************************************15********************************************
# ****************************************15********************************************
# ****************************************15********************************************
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            5     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.13040D+01    |proj g|=  3.87061D+00
#  Warning:  more than 10 function and gradient
#    evaluations in the last line search.  Termination
#    may possibly be caused by a bad search direction.
# /opt/conda/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
#  This problem is unconstrained.
# At iterate    5    f=  8.87684D+00    |proj g|=  7.80159D-02
#
# At iterate   10    f=  8.73532D+00    |proj g|=  2.69490D-03
#
# At iterate   15    f=  8.72234D+00    |proj g|=  6.59353D-04
#
# At iterate   20    f=  8.71956D+00    |proj g|=  9.16560D-04
#
# At iterate   25    f=  8.71921D+00    |proj g|=  4.29233D-03
#
# At iterate   30    f=  8.71873D+00    |proj g|=  1.25411D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     5     30     64      1     0     0   1.254D-03   8.719D+00
#   F =   8.7187315152272458
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# ****************************************16********************************************
# ****************************************16********************************************
# ****************************************16********************************************
# ****************************************16********************************************
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.03294D+01    |proj g|=  1.26539D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      2      4      1     0     0   1.358D-06   1.033D+01
#   F =   10.329353355926491
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
#  This problem is unconstrained.
# /opt/conda/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
#  This problem is unconstrained.
# ****************************************17********************************************
# ****************************************17********************************************
# ****************************************17********************************************
# ****************************************17********************************************
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.08925D+01    |proj g|=  2.14376D+00
#
# At iterate    5    f=  9.80496D+00    |proj g|=  2.87614D-02
#
# At iterate   10    f=  9.77302D+00    |proj g|=  1.89973D-03
#
# At iterate   15    f=  9.76970D+00    |proj g|=  5.78916D-04
#
# At iterate   20    f=  9.76944D+00    |proj g|=  2.10768D-04
#
# At iterate   25    f=  9.76838D+00    |proj g|=  6.36291D-07
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     25     28      1     0     0   6.363D-07   9.768D+00
#   F =   9.7683819000401417
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ****************************************18********************************************
# ****************************************18********************************************
# ****************************************18********************************************
# ****************************************18********************************************
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  9.51944D+00    |proj g|=  5.15909D-02
#  This problem is unconstrained.
# At iterate    5    f=  9.47464D+00    |proj g|=  6.56269D-03
#
# At iterate   10    f=  9.46762D+00    |proj g|=  1.44077D-04
#
# At iterate   15    f=  9.23727D+00    |proj g|=  1.08199D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     16     35      1     0     0   1.083D-02   9.237D+00
#   F =   9.2372659746536669
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# ****************************************19********************************************
# ****************************************19********************************************
# ****************************************19********************************************
# ****************************************19********************************************
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            5     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.27998D+01    |proj g|=  5.76149D+00
#  Warning:  more than 10 function and gradient
#    evaluations in the last line search.  Termination
#    may possibly be caused by a bad search direction.
# /opt/conda/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
#  This problem is unconstrained.
# At iterate    5    f=  9.26651D+00    |proj g|=  4.87704D-02
#
# At iterate   10    f=  9.17259D+00    |proj g|=  8.83451D-03
#
# At iterate   15    f=  9.16303D+00    |proj g|=  1.12634D-03
#
# At iterate   20    f=  9.15904D+00    |proj g|=  1.09899D-03
#
# At iterate   25    f=  9.15440D+00    |proj g|=  8.87041D-03
#
# At iterate   30    f=  9.14489D+00    |proj g|=  3.36920D-03
#   ys=-3.490E-01  -gs= 9.724E-01 BFGS update SKIPPED
#  Warning:  more than 10 function and gradient
#    evaluations in the last line search.  Termination
#    may possibly be caused by a bad search direction.
#  This problem is unconstrained.
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     5     33     71      1     1     0   2.711D-03   8.822D+00
#   F =   8.8223056030726195
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# ****************************************20********************************************
# ****************************************20********************************************
# ****************************************20********************************************
# ****************************************20********************************************
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.09018D+01    |proj g|=  8.48610D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      2      4      1     0     0   8.866D-07   1.090D+01
#   F =   10.901759705810923
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ****************************************21********************************************
# ****************************************21********************************************
# ****************************************21********************************************
# ****************************************21********************************************
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.14741D+01    |proj g|=  2.26373D+00
#
# At iterate    5    f=  1.03600D+01    |proj g|=  2.87204D-02
# /opt/conda/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
#  This problem is unconstrained.
# At iterate   10    f=  1.03300D+01    |proj g|=  4.82168D-03
#
# At iterate   15    f=  1.03248D+01    |proj g|=  9.65940D-05
#
# At iterate   20    f=  1.03244D+01    |proj g|=  8.14278D-04
#
# At iterate   25    f=  1.03235D+01    |proj g|=  3.63608D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     26     29      1     0     0   1.905D-06   1.032D+01
#   F =   10.323494567461328
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ****************************************22********************************************
# ****************************************22********************************************
# ****************************************22********************************************
# ****************************************22********************************************
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.14394D+01    |proj g|=  2.19610D+00
# /opt/conda/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
#  This problem is unconstrained.
# At iterate    5    f=  1.00832D+01    |proj g|=  3.12646D-02
#
# At iterate   10    f=  1.00405D+01    |proj g|=  5.82795D-03
#
# At iterate   15    f=  1.00347D+01    |proj g|=  1.17542D-04
#
# At iterate   20    f=  9.94337D+00    |proj g|=  4.25872D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     20     42      1     0     0   4.259D-03   9.943D+00
#   F =   9.9433720232088074
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# ****************************************23********************************************
# ****************************************23********************************************
# ****************************************23********************************************
# ****************************************23********************************************
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            5     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.40566D+01    |proj g|=  7.14550D+00
#  Warning:  more than 10 function and gradient
#    evaluations in the last line search.  Termination
#    may possibly be caused by a bad search direction.
# /opt/conda/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
#  This problem is unconstrained.
# At iterate    5    f=  9.72807D+00    |proj g|=  5.23760D-02
#
# At iterate   10    f=  9.63885D+00    |proj g|=  5.52730D-03
#
# At iterate   15    f=  9.62988D+00    |proj g|=  1.49129D-04
#  Bad direction in the line search;
#    refresh the lbfgs memory and restart the iteration.
# /opt/conda/lib/python3.9/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#
#  Line search cannot locate an adequate point after 20 function
#   and gradient evaluations.  Previous x, f and g restored.
#  Possible causes: 1 error in function or gradient evaluation;
#                   2 rounding error dominate computation.
#  This problem is unconstrained.
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     5     20     80      2     0     0   1.346D+01   9.548D+00
#   F =   9.5479314310692462
#
# ABNORMAL_TERMINATION_IN_LNSRCH
# ****************************************24********************************************
# ****************************************24********************************************
# ****************************************24********************************************
# ****************************************24********************************************
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  9.47553D+00    |proj g|=  8.21471D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3      4      6      1     0     0   2.060D-06   9.475D+00
#   F =   9.4754056076951301
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ****************************************25********************************************
# ****************************************25********************************************
# ****************************************25********************************************
# ****************************************25********************************************
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  9.15859D+00    |proj g|=  3.11488D-01
#  This problem is unconstrained.
# At iterate    5    f=  9.07048D+00    |proj g|=  1.46666D-02
#
# At iterate   10    f=  9.05432D+00    |proj g|=  8.44111D-03
#
# At iterate   15    f=  9.05127D+00    |proj g|=  1.41343D-03
#
# At iterate   20    f=  9.05102D+00    |proj g|=  1.42571D-04
#
# At iterate   25    f=  9.01202D+00    |proj g|=  6.47710D-02
#
# At iterate   30    f=  9.00251D+00    |proj g|=  4.94769D-06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     30     34      1     0     0   4.948D-06   9.003D+00
#   F =   9.0025116206171898
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ****************************************26********************************************
# ****************************************26********************************************
# ****************************************26********************************************
# ****************************************26********************************************
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            5     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  9.76922D+00    |proj g|=  1.23467D+00
# /opt/conda/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
#  This problem is unconstrained.
# At iterate    5    f=  8.80372D+00    |proj g|=  2.19573D-02
#
# At iterate   10    f=  8.78503D+00    |proj g|=  4.36149D-03
#
# At iterate   15    f=  8.78241D+00    |proj g|=  1.11708D-02
#
# At iterate   20    f=  8.63339D+00    |proj g|=  9.93930D-02
#
# At iterate   25    f=  8.60401D+00    |proj g|=  5.51969D-02
#
# At iterate   30    f=  8.59957D+00    |proj g|=  3.61524D-04
#
# At iterate   35    f=  8.59480D+00    |proj g|=  1.46250D-02
#  Bad direction in the line search;
#    refresh the lbfgs memory and restart the iteration.
# At iterate   40    f=  8.58940D+00    |proj g|=  3.43311D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     5     43     82      2     0     0   1.428D-04   8.589D+00
#   F =   8.5893868833012430
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# ****************************************27********************************************
# ****************************************27********************************************
# ****************************************27********************************************
# ****************************************27********************************************
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            6     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  9.99132D+00    |proj g|=  1.56256D+00
# /opt/conda/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
#  This problem is unconstrained.
# At iterate    5    f=  8.83889D+00    |proj g|=  3.33045D-02
#
# At iterate   10    f=  8.74975D+00    |proj g|=  1.95535D-01
#
# At iterate   15    f=  8.62283D+00    |proj g|=  2.37208D-02
#
# At iterate   20    f=  8.60500D+00    |proj g|=  2.99977D-03
#  Warning:  more than 10 function and gradient
#    evaluations in the last line search.  Termination
#    may possibly be caused by a bad search direction.
#  This problem is unconstrained.
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     6     21     49      1     0     0   3.082D-03   8.605D+00
#   F =   8.6050000631240522
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# ****************************************28********************************************
# ****************************************28********************************************
# ****************************************28********************************************
# ****************************************28********************************************
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  9.97338D+00    |proj g|=  3.25497D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3      3      5      1     0     0   3.780D-06   9.973D+00
#   F =   9.9733515812264830
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ****************************************29********************************************
# ****************************************29********************************************
# ****************************************29********************************************
# ****************************************29********************************************
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  9.62016D+00    |proj g|=  3.38093D-01
#  This problem is unconstrained.
# At iterate    5    f=  9.52672D+00    |proj g|=  1.20235D-02
#
# At iterate   10    f=  9.51161D+00    |proj g|=  3.33993D-03
#
# At iterate   15    f=  9.50992D+00    |proj g|=  8.33292D-04
#
# At iterate   20    f=  9.50979D+00    |proj g|=  1.02051D-04
#
# At iterate   25    f=  9.46522D+00    |proj g|=  5.09852D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     28     38      1     0     0   1.727D-07   9.465D+00
# ...
#
# Machine precision = 2.220D-16
#  N =            8     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  9.36715D+00    |proj g|=  1.13792D+00
#
# At iterate    5    f=  8.75754D+00    |proj g|=  1.42240D-01
#
# At iterate   10    f=  8.58172D+00    |proj g|=  4.38899D-02
#
# At iterate   15    f=  8.55620D+00    |proj g|=  9.70355D-03
#
# At iterate   20    f=  8.55530D+00    |proj g|=  1.22478D-03
#
# At iterate   25    f=  8.55502D+00    |proj g|=  2.66747D-04
#
# At iterate   30    f=  8.55493D+00    |proj g|=  2.70167D-03
#
# At iterate   35    f=  8.52971D+00    |proj g|=  1.18123D-02
#
# At iterate   40    f=  8.48868D+00    |proj g|=  2.15014D-02
#
# At iterate   45    f=  8.48799D+00    |proj g|=  3.50134D-04
#  This problem is unconstrained.
# /opt/conda/lib/python3.9/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# At iterate   50    f=  8.48761D+00    |proj g|=  2.41473D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     8     50     77      1     0     0   2.415D-03   8.488D+00
#   F =   8.4876059183014831
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# ****************************************52********************************************
# ****************************************52********************************************
# ****************************************52********************************************
# ****************************************52********************************************
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            5     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  9.47630D+00    |proj g|=  9.24760D-03
#
# At iterate    5    f=  9.47621D+00    |proj g|=  4.22104D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     5      7     10      1     0     0   5.371D-06   9.476D+00
#   F =   9.4762061633454415
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ****************************************53********************************************
# ****************************************53********************************************
# ****************************************53********************************************
# ****************************************53********************************************
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            6     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.29461D+01    |proj g|=  5.12893D+00
# /opt/conda/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
#  This problem is unconstrained.
# At iterate    5    f=  9.27695D+00    |proj g|=  8.40284D-02
#
# At iterate   10    f=  9.21795D+00    |proj g|=  2.18739D-02
#
# At iterate   15    f=  9.20930D+00    |proj g|=  6.43291D-03
#
# At iterate   20    f=  9.20848D+00    |proj g|=  1.61832D-03
#
# At iterate   25    f=  9.20846D+00    |proj g|=  2.62767D-04
#
# At iterate   30    f=  9.19739D+00    |proj g|=  3.16579D-02
#
# At iterate   35    f=  9.11902D+00    |proj g|=  4.50530D-02
#
# At iterate   40    f=  9.08350D+00    |proj g|=  1.14411D-02
#
# At iterate   45    f=  9.08261D+00    |proj g|=  4.64656D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     6     46     53      1     0     0   1.117D-05   9.083D+00
#   F =   9.0826063179148555
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# ****************************************54********************************************
# ****************************************54********************************************
# ****************************************54********************************************
# ****************************************54********************************************
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            7     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  9.65576D+00    |proj g|=  9.50637D-01
# /opt/conda/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
#  This problem is unconstrained.
# At iterate    5    f=  9.21200D+00    |proj g|=  2.95995D-02
#
# At iterate   10    f=  9.06166D+00    |proj g|=  1.87645D-01
#
# At iterate   15    f=  8.96235D+00    |proj g|=  9.45019D-03
#
# At iterate   20    f=  8.95276D+00    |proj g|=  1.22565D-02
#
# At iterate   25    f=  8.95145D+00    |proj g|=  4.01206D-04
#
# At iterate   30    f=  8.95143D+00    |proj g|=  2.14687D-03
#
# At iterate   35    f=  8.87198D+00    |proj g|=  6.09261D-02
#
# At iterate   40    f=  8.81862D+00    |proj g|=  1.18239D-01
#
# At iterate   45    f=  8.79769D+00    |proj g|=  1.31199D-01
# /opt/conda/lib/python3.9/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# At iterate   50    f=  8.73638D+00    |proj g|=  4.53246D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     7     50     82      1     0     0   4.532D-02   8.736D+00
#   F =   8.7363824997292134
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# ****************************************55********************************************
# ****************************************55********************************************
# ****************************************55********************************************
# ****************************************55********************************************
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            8     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  9.80472D+00    |proj g|=  1.25886D+00
# /opt/conda/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
#  This problem is unconstrained.
# At iterate    5    f=  9.02709D+00    |proj g|=  7.45164D-02
#
# At iterate   10    f=  8.91364D+00    |proj g|=  2.21963D-02
#
# At iterate   15    f=  8.90697D+00    |proj g|=  9.62874D-03
#
# At iterate   20    f=  8.90452D+00    |proj g|=  7.33312D-04
#
# At iterate   25    f=  8.90419D+00    |proj g|=  4.65947D-04
#
# At iterate   30    f=  8.90404D+00    |proj g|=  6.09535D-03
#
# At iterate   35    f=  8.86515D+00    |proj g|=  4.97444D-02
#
# At iterate   40    f=  8.84951D+00    |proj g|=  2.09438D-02
#
# At iterate   45    f=  8.82854D+00    |proj g|=  7.83123D-03
#
# At iterate   50    f=  8.82844D+00    |proj g|=  3.17175D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     8     50     81      1     0     0   3.172D-03   8.828D+00
#   F =   8.8284444899621182
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# /opt/conda/lib/python3.9/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# ****************************************56********************************************
# ****************************************56********************************************
# ****************************************56********************************************
# ****************************************56********************************************
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            5     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  9.90454D+00    |proj g|=  9.19796D-03
#  This problem is unconstrained.
# At iterate    5    f=  9.90439D+00    |proj g|=  2.78127D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     5      7      9      1     0     0   6.021D-06   9.904D+00
#   F =   9.9043897613172796
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ****************************************57********************************************
# ****************************************57********************************************
# ****************************************57********************************************
# ****************************************57********************************************
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            6     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.48181D+01    |proj g|=  7.12249D+00
# /opt/conda/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
#  This problem is unconstrained.
# At iterate    5    f=  9.68785D+00    |proj g|=  9.23886D-02
#
# At iterate   10    f=  9.63419D+00    |proj g|=  1.33375D-02
#
# At iterate   15    f=  9.61924D+00    |proj g|=  9.99923D-03
#
# At iterate   20    f=  9.61773D+00    |proj g|=  2.88839D-03
#
# At iterate   25    f=  9.61766D+00    |proj g|=  1.10402D-04
#
# At iterate   30    f=  9.60605D+00    |proj g|=  1.14799D-01
#
# At iterate   35    f=  9.47308D+00    |proj g|=  2.29240D-02
#
# At iterate   40    f=  9.47127D+00    |proj g|=  1.14010D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     6     42     52      1     0     0   5.576D-06   9.471D+00
#   F =   9.4712740808065270
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ****************************************58********************************************
# ****************************************58********************************************
# ****************************************58********************************************
# ****************************************58********************************************
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            7     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.00848D+01    |proj g|=  8.79472D-01
# /opt/conda/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
#  This problem is unconstrained.
# At iterate    5    f=  9.63592D+00    |proj g|=  6.30171D-02
#
# At iterate   10    f=  9.34419D+00    |proj g|=  6.29686D-02
#
# At iterate   15    f=  9.32416D+00    |proj g|=  1.52447D-02
#
# At iterate   20    f=  9.31756D+00    |proj g|=  4.61343D-03
#
# At iterate   25    f=  9.31704D+00    |proj g|=  2.03240D-04
#
# At iterate   30    f=  9.31701D+00    |proj g|=  1.09123D-03
#
# At iterate   35    f=  9.30010D+00    |proj g|=  6.24491D-02
#  Nonpositive definiteness in Cholesky factorization in formt;
#    refresh the lbfgs memory and restart the iteration.
#  This problem is unconstrained.
# ****************************************59********************************************
# ****************************************59********************************************
# ****************************************59********************************************
# ****************************************59********************************************
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            8     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.00975D+01    |proj g|=  7.25040D-01
#
# At iterate    5    f=  9.40030D+00    |proj g|=  7.31100D-02
#
# At iterate   10    f=  9.35114D+00    |proj g|=  1.05841D-02
#
# At iterate   15    f=  9.32810D+00    |proj g|=  2.97520D-02
#
# At iterate   20    f=  9.32397D+00    |proj g|=  7.57864D-03
#
# At iterate   25    f=  9.24553D+00    |proj g|=  1.83561D-01
#
# At iterate   30    f=  9.19459D+00    |proj g|=  3.63868D-02
#
# At iterate   35    f=  9.17959D+00    |proj g|=  5.96947D-03
#
# At iterate   40    f=  9.17627D+00    |proj g|=  3.52011D-03
#
# At iterate   45    f=  9.17561D+00    |proj g|=  1.16277D-03
#  Bad direction in the line search;
#    refresh the lbfgs memory and restart the iteration.
# /opt/conda/lib/python3.9/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# At iterate   50    f=  9.17544D+00    |proj g|=  7.04382D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     8     50     92      2     0     0   7.044D-04   9.175D+00
#   F =   9.1754371572192976
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT

# %%
sorted(aies)
# Out:
# [(14.0, (3, 5, 3)),
#  (21880.072845544622, (4, 5, 3)),
#  (21976.173450493083, (3, 5, 2)),
#  (22090.785144070534, (4, 5, 2)),
#  (22136.260611384, (2, 5, 2)),
#  (22178.480162607557, (2, 5, 3)),
#  (22469.452383225387, (1, 5, 3)),
#  (22510.055748128543, (4, 5, 1)),
#  (22518.921319302455, (4, 6, 2)),
#  (22544.89670547715, (1, 5, 2)),
#  (22625.0101999291, (0, 5, 3)),
#  (22736.25923351507, (1, 6, 3)),
#  (22751.46282183368, (3, 5, 1)),
#  (22758.07300614242, (4, 6, 3)),
#  (22950.269045413916, (3, 6, 3)),
#  (23198.469934709883, (2, 5, 1)),
#  (23247.253113577273, (3, 6, 2)),
#  (23314.095913192767, (2, 6, 3)),
#  (23408.793874948668, (4, 6, 1)),
#  (23420.891366705953, (4, 5, 0)),
#  (23437.591067446352, (0, 5, 2)),
#  (23651.92611699691, (4, 7, 3)),
#  (23729.551696038987, (0, 6, 3)),
#  (23766.34941733483, (2, 6, 2)),
#  (23788.927184821725, (3, 6, 1)),
#  (23803.197150707845, (1, 6, 2)),
#  (23803.460526392766, (1, 5, 1)),
#  (23809.163553618102, (3, 5, 0)),
#  (24041.581468419805, (3, 7, 3)),
#  (24064.277283334908, (3, 7, 2)),
#  (24390.30024656805, (2, 6, 1)),
#  (24410.002032157616, (4, 7, 1)),
#  (24414.644845422656, (2, 5, 0)),
#  (24420.707076777857, (4, 6, 0)),
#  (24470.63582343505, (2, 7, 3)),
#  (24605.471366434376, (1, 7, 3)),
#  (24865.532658140335, (2, 7, 2)),
#  (24950.825856482927, (3, 7, 1)),
#  (24961.967490779396, (3, 6, 0)),
#  (24996.209329089026, (0, 6, 2)),
#  (24999.105587661867, (0, 5, 1)),
#  (25169.351774503404, (1, 6, 1)),
#  (25180.664601402714, (1, 5, 0)),
#  (25523.70802515331, (4, 7, 0)),
#  (25622.126331785887, (1, 7, 2)),
#  (25674.87804790024, (2, 7, 1)),
#  (25697.35367323942, (2, 6, 0)),
#  (26208.881034015743, (3, 7, 0)),
#  (26349.20452605476, (0, 7, 3)),
#  (26599.32200578038, (1, 7, 1)),
#  (26607.554191383242, (0, 6, 1)),
#  (26612.157864994017, (0, 7, 2)),
#  (26612.414244866643, (1, 6, 0)),
#  (26618.452945220397, (0, 5, 0)),
#  (27037.40995818908, (2, 7, 0)),
#  (28086.93300216894, (1, 7, 0)),
#  (28241.736022706267, (0, 7, 1)),
#  (28254.65787633341, (0, 6, 0)),
#  (29908.38768541404, (0, 7, 0))]
