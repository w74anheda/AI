# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as PLT
from tensorflow.keras import models, layers, optimizers
from tensorflow.keras.applications.resnet import ResNet152, preprocess_input, decode_predictions
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import Sequential, Model,Input
from tensorflow.keras.layers import Dense, Flatten, Conv2D, MaxPool2D,ZeroPadding2D, Dropout
from tensorflow.keras.utils import to_categorical
import os,glob,random,shutil
from pathlib import Path
from tensorflow.keras.optimizers.legacy import Adam
os.path.expanduser('/home/masoud/.keras/')
# Out:
# '/home/masoud/.keras/'

# %%
import tensorflow as tf; print(tf.config.list_physical_devices('GPU'))
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
data_path = os.path.abspath(os.path.join('__file__', '../../../../datasets/15-Scene/data/'))
train_test_path = os.path.abspath(os.path.join('__file__', '../../../../datasets/15-Scene/train_test/'))
train_path = os.path.abspath(os.path.join(train_test_path, '../../../datasets/15-Scene/train_test/train/'))
test_path = os.path.abspath(os.path.join(train_test_path, '../../../datasets/15-Scene/train_test/test/'))

# %%
train_count = 100

if os.path.isdir(train_test_path):
    shutil.rmtree(train_test_path)
Path(f'{train_test_path}').mkdir(parents=True, exist_ok=True)

for category in os.listdir(data_path):
    images = glob.glob(f'{data_path}/{category}/*')
    random.shuffle(images)
    
    # train data
    Path(f'{train_path}/{category}/').mkdir(parents=True, exist_ok=True)
    
    for img in images[:train_count]:
        shutil.copyfile(img, f'{train_path}/{category}/{img.split("/")[-1]}')
        
    # test data
    Path(f'{test_path}/{category}/').mkdir(parents=True, exist_ok=True)
    for img in images[train_count:]:
        shutil.copyfile(img, f'{test_path}/{category}/{img.split("/")[-1]}')

# %%
image_generator = ImageDataGenerator(
    rescale=1.0/255.0
)
batch_size = 15

generator = image_generator.flow_from_directory(
    train_path,
    class_mode='categorical',
    batch_size=batch_size,
    target_size=(150,150)
)

generator_test = image_generator.flow_from_directory(
    test_path,
    class_mode='categorical',
    batch_size=batch_size,
    target_size=(150,150)
)
# Out:
# Found 1500 images belonging to 15 classes.
# Found 2985 images belonging to 15 classes.

# %%
model = Sequential([
 
    
    Conv2D(128, 3, strides=1, activation='relu', padding='same'),
    MaxPool2D(pool_size=16, strides=2),
    
    Conv2D(64, 3, strides=1, activation='relu'),
    MaxPool2D(pool_size=8, strides=2),
    
    
    Conv2D(32, 3, strides=1, activation='relu'),
    MaxPool2D(pool_size=4, strides=2),
    
    
    Conv2D(32, 3, strides=1, activation='relu'),
    MaxPool2D(pool_size=2, strides=2),
    
    
    Conv2D(32, 3, strides=1, activation='relu'),
    MaxPool2D(pool_size=2, strides=2),
    
    
    Flatten(),
    Dense(100, activation='relu'),
    Dropout(0.5),
    Dense(15, activation='softmax')
])

model.compile(optimizer=Adam(), loss='categorical_crossentropy', metrics=['accuracy'])

# %%
history = model.fit(
    generator,
    validation_data=generator_test,
    epochs=200,
)
# Out:
# Epoch 1/200
# 100/100 [==============================] - 5s 52ms/step - loss: 1.8474 - accuracy: 0.3633 - val_loss: 1.9246 - val_accuracy: 0.3377
# Epoch 2/200
# 100/100 [==============================] - 5s 52ms/step - loss: 1.7982 - accuracy: 0.3833 - val_loss: 1.8767 - val_accuracy: 0.3367
# Epoch 3/200
# 100/100 [==============================] - 5s 51ms/step - loss: 1.7675 - accuracy: 0.3853 - val_loss: 1.7947 - val_accuracy: 0.3839
# Epoch 4/200
# 100/100 [==============================] - 5s 52ms/step - loss: 1.7078 - accuracy: 0.4000 - val_loss: 1.7784 - val_accuracy: 0.3916
# Epoch 5/200
# 100/100 [==============================] - 5s 51ms/step - loss: 1
200
# 100/100 [==============================] - 5s 51ms/step - loss: 0.3338 - accuracy: 0.8787 - val_loss: 4.9589 - val_accuracy: 0.4107
# Epoch 156/200
# 100/100 [==============================] - 5s 51ms/step - loss: 0.3334 - accuracy: 0.8773 - val_loss: 4.6998 - val_accuracy: 0.4184
# Epoch 157/200
# 100/100 [==============================] - 5s 51ms/step - loss: 0.2937 - accuracy: 0.9007 - val_loss: 4.9208 - val_accuracy: 0.4121
# Epoch 158/200
# 100/100 [==============================] - 5s 52ms/step - loss: 0.3808 - accuracy: 0.8593 - val_loss: 4.9762 - val_accuracy: 0.4191
# Epoch 159/200
# 100/100 [==============================] - 5s 51ms/step - loss: 0.3616 - accuracy: 0.8787 - val_loss: 5.1495 - val_accuracy: 0.4157
# Epoch 160/200
# 100/100 [==============================] - 5s 51ms/step - loss: 0.3374 - accuracy: 0.8800 - val_loss: 5.1615 - val_accuracy: 0.4295
# Epoch 161/200
# 100/100 [==============================] - 5s 52ms/step - loss: 0.3683 - accuracy: 0.8607 - val_loss: 4.7681 - val_accuracy: 0.3983
# Epoch 162/200
# 100/100 [==============================] - 5s 51ms/step - loss: 0.3349 - accuracy: 0.8873 - val_loss: 4.9613 - val_accuracy: 0.4174
# Epoch 163/200
# 100/100 [==============================] - 5s 51ms/step - loss: 0.2894 - accuracy: 0.8927 - val_loss: 5.1383 - val_accuracy: 0.4161
# Epoch 164/200
# 100/100 [==============================] - 5s 52ms/step - loss: 0.2473 - accuracy: 0.9040 - val_loss: 5.3986 - val_accuracy: 0.4124
# Epoch 165/200
# 100/100 [==============================] - 5s 51ms/step - loss: 0.4602 - accuracy: 0.8393 - val_loss: 5.0262 - val_accuracy: 0.4157
# Epoch 166/200
# 100/100 [==============================] - 5s 51ms/step - loss: 0.4010 - accuracy: 0.8620 - val_loss: 4.7756 - val_accuracy: 0.4131
# Epoch 167/200
# 100/100 [==============================] - 5s 51ms/step - loss: 0.3679 - accuracy: 0.8773 - val_loss: 4.8052 - val_accuracy: 0.4151
# Epoch 168/200
# 100/100 [==============================] - 5s 51ms/step - loss: 0.3382 - accuracy: 0.8727 - val_loss: 5.1695 - val_accuracy: 0.4094
# Epoch 169/200
# 100/100 [==============================] - 5s 51ms/step - loss: 0.3119 - accuracy: 0.8873 - val_loss: 5.3199 - val_accuracy: 0.3966
# Epoch 170/200
# 100/100 [==============================] - 5s 52ms/step - loss: 0.2876 - accuracy: 0.8973 - val_loss: 5.3673 - val_accuracy: 0.4037
# Epoch 171/200
# 100/100 [==============================] - 5s 51ms/step - loss: 0.2799 - accuracy: 0.9053 - val_loss: 5.3583 - val_accuracy: 0.4010
# Epoch 172/200
# 100/100 [==============================] - 5s 51ms/step - loss: 0.3037 - accuracy: 0.8927 - val_loss: 5.2727 - val_accuracy: 0.4080
# Epoch 173/200
# 100/100 [==============================] - 5s 51ms/step - loss: 0.2805 - accuracy: 0.9033 - val_loss: 5.4796 - val_accuracy: 0.4057
# Epoch 174/200
# 100/100 [==============================] - 5s 51ms/step - loss: 0.3685 - accuracy: 0.8767 - val_loss: 5.3368 - val_accuracy: 0.4151
# Epoch 175/200
# 100/100 [==============================] - 5s 52ms/step - loss: 0.3329 - accuracy: 0.8787 - val_loss: 5.3268 - val_accuracy: 0.4080
# Epoch 176/200
# 100/100 [==============================] - 5s 51ms/step - loss: 0.2546 - accuracy: 0.9013 - val_loss: 5.6780 - val_accuracy: 0.4255
# Epoch 177/200
# 100/100 [==============================] - 5s 51ms/step - loss: 0.4130 - accuracy: 0.8693 - val_loss: 5.0465 - val_accuracy: 0.4007
# Epoch 178/200
# 100/100 [==============================] - 5s 51ms/step - loss: 0.3154 - accuracy: 0.8847 - val_loss: 5.4376 - val_accuracy: 0.4164
# Epoch 179/200
# 100/100 [==============================] - 5s 51ms/step - loss: 0.3277 - accuracy: 0.8793 - val_loss: 5.8675 - val_accuracy: 0.4040
# Epoch 180/200
# 100/100 [==============================] - 5s 52ms/step - loss: 0.3303 - accuracy: 0.8893 - val_loss: 5.4905 - val_accuracy: 0.4054
# Epoch 181/200
# 100/100 [==============================] - 5s 51ms/step - loss: 0.3779 - accuracy: 0.8653 - val_loss: 5.6669 - val_accuracy: 0.4060
# Epoch 182/200
# 100/100 [==============================] - 5s 52ms/step - loss: 0.2028 - accuracy: 0.9273 - val_loss: 5.7240 - val_accuracy: 0.4221
# Epoch 183/200
# 100/100 [==============================] - 5s 52ms/step - loss: 0.2622 - accuracy: 0.9033 - val_loss: 5.9854 - val_accuracy: 0.4047
# Epoch 184/200
# 100/100 [==============================] - 5s 52ms/step - loss: 0.4960 - accuracy: 0.8453 - val_loss: 5.1242 - val_accuracy: 0.4134
# Epoch 185/200
# 100/100 [==============================] - 5s 51ms/step - loss: 0.3220 - accuracy: 0.8827 - val_loss: 5.7023 - val_accuracy: 0.4151
# Epoch 186/200
# 100/100 [==============================] - 5s 51ms/step - loss: 0.4119 - accuracy: 0.8480 - val_loss: 5.3293 - val_accuracy: 0.3953
# Epoch 187/200
# 100/100 [==============================] - 5s 52ms/step - loss: 0.3598 - accuracy: 0.8733 - val_loss: 5.1727 - val_accuracy: 0.4191
# Epoch 188/200
# 100/100 [==============================] - 5s 51ms/step - loss: 0.2366 - accuracy: 0.9153 - val_loss: 5.5349 - val_accuracy: 0.4258
# Epoch 189/200
# 100/100 [==============================] - 5s 51ms/step - loss: 0.3986 - accuracy: 0.8660 - val_loss: 5.8788 - val_accuracy: 0.3950
# Epoch 190/200
# 100/100 [==============================] - 5s 51ms/step - loss: 0.3018 - accuracy: 0.8927 - val_loss: 5.5230 - val_accuracy: 0.4111
# Epoch 191/200
# 100/100 [==============================] - 5s 51ms/step - loss: 0.3241 - accuracy: 0.8880 - val_loss: 5.3608 - val_accuracy: 0.4194
# Epoch 192/200
# 100/100 [==============================] - 5s 51ms/step - loss: 0.3340 - accuracy: 0.8967 - val_loss: 5.7239 - val_accuracy: 0.4275
# Epoch 193/200
# 100/100 [==============================] - 5s 51ms/step - loss: 0.2353 - accuracy: 0.9120 - val_loss: 6.0704 - val_accuracy: 0.4208
# Epoch 194/200
# 100/100 [==============================] - 5s 51ms/step - loss: 0.2797 - accuracy: 0.8987 - val_loss: 6.1951 - val_accuracy: 0.4047
# Epoch 195/200
# 100/100 [==============================] - 5s 51ms/step - loss: 0.2800 - accuracy: 0.9033 - val_loss: 5.9005 - val_accuracy: 0.4191
# Epoch 196/200
# 100/100 [==============================] - 5s 51ms/step - loss: 0.2475 - accuracy: 0.9153 - val_loss: 5.7376 - val_accuracy: 0.4141
# Epoch 197/200
# 100/100 [==============================] - 5s 51ms/step - loss: 0.2201 - accuracy: 0.9127 - val_loss: 6.4451 - val_accuracy: 0.4067
# Epoch 198/200
# 100/100 [==============================] - 5s 51ms/step - loss: 0.2568 - accuracy: 0.9060 - val_loss: 5.9279 - val_accuracy: 0.4221
# Epoch 199/200
# 100/100 [==============================] - 5s 51ms/step - loss: 0.2940 - accuracy: 0.8987 - val_loss: 6.0783 - val_accuracy: 0.4104
# Epoch 200/200
# 100/100 [==============================] - 5s 51ms/step - loss: 0.3099 - accuracy: 0.8980 - val_loss: 6.0998 - val_accuracy: 0.4127

# %%
PLT.plot(history.history['accuracy'],color='green')
PLT.plot(history.history['val_accuracy'],color='red')

# %%
model.save('15-scene')
# model = models.load_model('15-scene')

# %%
model.evaluate(generator_test)
# Out:
# 199/199 [==============================] - 3s 13ms/step - loss: 2.7058 - accuracy: 0.0697
# [2.7058448791503906, 0.06968174129724503]

# %% [markdown]
# # ResNet Evaluation

# %%
resnet152 = ResNet152(weights='imagenet', input_shape=generator.image_shape, include_top=False)

# %%
resnet_model = models.Sequential()
resnet_model.add(resnet152)
resnet_model.add(Flatten())
resnet_model.add(Dense(15, activation='softmax'))
resnet_model.compile(optimizer=Adam(), loss='categorical_crossentropy', metrics=['accuracy'])

# %%
resnet_history = resnet_model.fit(
    generator,
    validation_data=generator_test,
    epochs=200,
)
# Out:
# Epoch 1/200
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_33308/887609572.py in <module>
# ----> 1 history = resnet_model.fit(
#       2     generator,
#       3     validation_data=generator_test,
#       4     epochs=200,
#       5 )
#
# ~/anaconda3/lib/python3.9/site-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~/anaconda3/lib/python3.9/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1648                         ):
#    1649                             callbacks.on_train_batch_begin(step)
# -> 1650                             tmp_logs = self.train_function(iterator)
#    1651                             if data_handler.should_sync:
#    1652                                 context.async_wait()
#
# ~/anaconda3/lib/python3.9/site-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~/anaconda3/lib/python3.9/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in __call__(self, *args, **kwds)
#     878
#     879       with OptionalXlaContext(self._jit_compile):
# --> 880         result = self._call(*args, **kwds)
#     881
#     882       new_tracing_count = self.experimental_get_tracing_count()
#
# ~/anaconda3/lib/python3.9/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in _call(self, *args, **kwds)
#     943         # Lifting succeeded, so variables are initialized and we can run the
#     944         # no_variable_creation function.
# --> 945         return self._no_variable_creation_fn(*args, **kwds)
#     946     else:
#     947       _, _, filtered_flat_args = (
#
# ~/anaconda3/lib/python3.9/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compiler.py in __call__(self, *args, **kwargs)
#     132       (concrete_function,
#     133        filtered_flat_args) = self._maybe_define_function(args, kwargs)
# --> 134     return concrete_function._call_flat(
#     135         filtered_flat_args, captured_inputs=concrete_function.captured_inputs)  # pylint: disable=protected-access
#     136
#
# ~/anaconda3/lib/python3.9/site-packages/tensorflow/python/eager/polymorphic_function/monomorphic_function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1743         and executing_eagerly):
#    1744       # No tape is watching; skip to running the function.
# -> 1745       return self._build_call_outputs(self._inference_function.call(
#    1746           ctx, args, cancellation_manager=cancellation_manager))
#    1747     forward_backward = self._select_forward_and_backward_functions(
#
# ~/anaconda3/lib/python3.9/site-packages/tensorflow/python/eager/polymorphic_function/monomorphic_function.py in call(self, ctx, args, cancellation_manager)
#     376       with _InterpolateFunctionError(self):
#     377         if cancellation_manager is None:
# --> 378           outputs = execute.execute(
#     379               str(self.signature.name),
#     380               num_outputs=self._num_outputs,
#
# ~/anaconda3/lib/python3.9/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      50   try:
#      51     ctx.ensure_initialized()
# ---> 52     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      53                                         inputs, attrs, num_outputs)
#      54   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
PLT.plot(resnet_history.history['accuracy'],color='green')
PLT.plot(resnet_history.history['val_accuracy'],color='red')
