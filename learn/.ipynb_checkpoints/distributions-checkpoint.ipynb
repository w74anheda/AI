# %%
import numpy as np
import pandas as pd
import os
from scipy import stats
import matplotlib.pyplot as PLT
import seaborn as SB

# %% [markdown]
# # <font color="orange">Continuous Distributions</font>
#   * normal
#   * uniform
#   * exponential

# %%
DT_norm = stats.norm.rvs(size=10000, loc=0, scale=1)
pd.Series(DT_norm).hist(bins=20)
# Out:
# <AxesSubplot:>

# %%
SB.displot(DT_norm, bins=100, kde=True)

# %%
DT_uniform = stats.uniform.rvs(size=10000, loc=0, scale=10)
SB.displot(DT_uniform, kde=True, bins=100)

# %%
DT_exponential = stats.expon.rvs(1/2,size=10000) # mean call time 2 mintue
SB.displot(DT_exponential, kde=True)

# %% [markdown]
# # <font color="orange">Discrete Distributions</font>
#   * bernoli
#   * binomial
#   * multinomial
#   * poisson

# %%
DT_bernoli = stats.bernoulli.rvs(size=10000, p=.3)
SB.displot(DT_bernoli)

# %%
DT_binomial = stats.binom.rvs(size=10000, p=.3, n=100)
SB.displot(DT_binomial)
DT_binomial
# Out:
# array([34, 32, 34, ..., 34, 40, 28])

# %%
icu = 0.3
ccu = 0.1
recovery = 0.6
DT_multinomial = stats.multinomial.rvs(100, [icu,ccu,recovery], size=365)
DT_multinomial = pd.DataFrame(DT_multinomial, columns=['icu','ccu','recovery'])

SB.displot(DT_multinomial, kde=True)

# %%
DT_poisson = stats.poisson.rvs(mu=7, size=1000)
print(DT_poisson)

SB.displot(DT_poisson)
# Out:
# [ 4  6  6  6  2 11  7 10  8  6  5  4  9  7  6  8  5  6  9  6 11  7  3  9
#   6 12 10  7  4  6  6  2  7  8  6  7  3  5  8  7  9 10  4  5 11  5  2 10
#   5  7  7  4  9  6  8  9  3  7  9  8  8  5  8  6  6 12  9  8  4  6  8  9
#   5  9  5  6  5  7  4  8  4  5  7  7  5 12 10  4  8  4  6  7  6  7  9  8
#   7 17  5  6  9  6  7  3  7  4  7  8  3  5  9  5  8  3  5  8  7  9  6  8
#   8  7  9  3  7  8  9 10  6  8  7 13  9  5  4 10 12  7  9  8  6 11  5 12
#  10  8 10  6 10 11  2  7  6  7  9 11  6  4  3  8 10 13  9  6 12 10  6  6
#   6  5  6 12  7  7  7  6  9  6  3  6  6  2  4  7  7 16 12  6  5  5  6  8
#   3  8 10  4 12 10  7  5  6  4  6  8  5  7  7  6  6  8  8  4  7  4 12  4
#   6  9  6  7  6  5  7  8  9  6  6  8  6  8  5  5  4  6  6  8  2  5  8 12
#   6  5 12  4  8  6  7  7  7 11  7  4  2  8  6  4  5  5 11  7 10 10  6  6
#   6  6 10  6  8 11  5 11  7  5  6  5  6  5 11 10  3 11  7  7  8  6  5 11
#   5  5 10  5  7  8  8  8 15  5  7  4  6 12  7  8 13  6 10  9 10  7 12  6
#   8  7  7  8  5  6  4  5  6  2  2  8  4  9  6 11  3  8  5 10  8  8  7  5
#   7  6  4  7  5  7 14  7  7  6  6 13  0  8  9  3  9  8  9  7  4  5  7  7
#   6  3  8  6  7 12 10 10  7  7  5  6  5 10  7  6  8  8  8  8  6  9 10  6
#   6  5  8  4  5  5  4  6 11  9 14 13  7  3  8 13  4  6  5 12  6  9  7 10
#   8  9  6  9  6  9  5  1  5  7 11  6 14  8  5  6  5  5  4 10  6  3  6  9
#   5  7  5  3  3  7  7  6  2  3  5  6  8 10 10  7 10 13  7  4  3  5  7  7
#   9  8  6  8  5  7  6  2  9  6  6  7  8  8  9  3  6  7 10 10  9  8  5  8
#  10 10  6  5  3  7 10  6  5 11  7  9  6 11 12 10  2 14  6  8 10 10 10  8
#  10  5  5  9  4  5  7 11  6  5 12  9  6  7  7  6  4  6  7  9  9  9  4  5
#   4  4 11  4  5  4 10  4 11  8  5  8  4  4  5  4  4  5  9  4  5  7 10  8
#  16  9  7  9  8 10  6  6  8  4  8 12 10  8 13 10  8  8  8  5  9 11  6  4
#   5  5 11  6  7  6  2  4 12  6 10  8  6  4 10  6  6  4  2  5  4  9  7  6
#   7 15 14  6  3 12  8  4  5  6 10 11  3  7  4  7  5 13  9  6  4  9 10  3
#   5  5  7  5  7  9  9 10  6  4  4  6  5  4  9  7  7 10  4  9  7  8  5  6
#   3  9  9 11  5  5  5  9  5  9  3  3  7  8 10  4  8  7  7  6  5 11 10  9
#   7  7  8  7 11  5  1 12  4  6  6  7  8  8  5  6  7  4  6  5 10  6  4  8
#   4  6  4  5  5  4  7  3 10  7  7  2  8  6  7 11  7 13  8  8  7  3  7  4
#   4  6  6 14 10  5  6  6  7  9  6 14  7  3  8  4 17 10  6  9  4  5  6  2
#   3  4  7  2  9 10  9 14  9  6  3  8 11  8  7  9  8 10  3  5 10  7  7  8
#   6  8  5  5  8  4  9 10  6 10  7 10  4  7  6  9  5  8 10  9  4  7  7  4
#   1 10  7  8  6 12  6 12 11  7  8  6  9  4  5  3 10  7  2  6  4 10  5 11
#   5  3  4  9  9  2  5  2  7  9  8  6  9  8  7  6  7 12  4  8 10  4  6  4
#  11  3  6  4  9  2  5  6  4  6 11  7  8  5  5  6  2  7  7  9 12  4  8  4
#   6 11  4  4  7  6 10  7  4  3  7  6  9  8  8  9  3  8  5  4  8  8  3  8
#   4  7 10  7  7  9 10 12  8  8  4  7  9  4  5  8  6  6  8  6  2  5  5 11
#   7 10  4 13  6  6  9  4 12 12  6  7  7  8  8  6  5  7  5 13  5  4  8  7
#   6  7  4  8  7  4 11  1  3  9 12  7  7  2 10  5  8  6  6 13  5 11  6  5
#   7  9  4  9  8  6  7  8  6  5  6  3  6  8  8  3 11  9 12  9  5  4  9  7
#   5  8  8  5  7  4  5  5 10  8  3 11  7  8  7  7]

# %% [markdown]
# # <font color="orange">PDF(Continuous) - PMF(discrete) - CDF</font>

# %%
DT_binomial = stats.binom(5000,.2)
TAKHT = 400
pmfsum = 0
# for i in range(1000, 5000):
#     pmfsum+= DT_binomial.pmf(i)
# print(pmfsum)
DT_binomial.cdf(5000) - DT_binomial.cdf(1000)
# Out:
# 0.505641740641464
# 0.49153823516345097

# %%
DT_poisson = stats.poisson(160) #160 moshtari dar rooz
1 - DT_poisson.cdf(150) # ehtemal 200 moshtari be bala da rooz
# Out:
# 0.7719677058307436

# %% [markdown]
# # <font color="orange">Comparison Distributions</font>
#  * Kullback Divergence (KL)

# %% [markdown]
# ### <font color="Brown">Kullback Divergence (KL)</font>

# %%
def KL_divergence(p,q):
    return np.sum(
        np.where(np.logical_and(p!=0,q!=0), p* np.log(p/q), 0 )
    )

# %%
DT_X = np.arange(-10,10,0.001)
p = stats.norm.pdf(DT_X,0,2)
q = stats.norm.pdf(DT_X,2,3)

PLT.plot(DT_X,p)
PLT.plot(DT_X,q, c='red')
KL_divergence(p,q)
# Out:
# 349.91348337868124

# %%
WH = pd.read_csv('../datasets/weight-height.csv')
WH.head()
# Out:
#   Gender     Height      Weight
# 0   Male  73.847017  241.893563
# 1   Male  68.781904  162.310473
# 2   Male  74.110105  212.740856
# 3   Male  71.730978  220.042470
# 4   Male  69.881796  206.349801

# %%
MH = WH[WH['Gender']=='Male']['Height']
NMH = stats.norm.rvs(size=len(MH), loc=MH.mean(), scale=MH.std())
PLT.hist(NMH,bins=100)
PLT.hist(MH,bins=100)
# Out:
# (array([  1.,   0.,   0.,   0.,   1.,   0.,   0.,   3.,   2.,   3.,   1.,
#           5.,   5.,   4.,   6.,   5.,   8.,   9.,   9.,  12.,  14.,   9.,
#          16.,  16.,  19.,  29.,  34.,  27.,  20.,  37.,  47.,  56.,  60.,
#          63.,  59.,  70.,  77.,  78.,  88.,  89.,  96., 101., 125., 131.,
#         127., 129., 148., 148., 150., 135., 122., 168., 145., 139., 151.,
#         134., 124., 112., 144.,  93., 133., 109.,  98., 115., 113., 103.,
#          83.,  79.,  62.,  61.,  46.,  50.,  40.,  43.,  42.,  34.,  28.,
#          30.,  16.,  20.,  13.,  11.,   8.,  11.,   5.,   8.,   4.,   7.,
#           8.,   4.,   3.,   1.,   3.,   0.,   0.,   1.,   0.,   2.,   1.,
#           1.]),
#  array([58.40690493, 58.61282331, 58.81874168, 59.02466005, 59.23057843,
#         59.4364968 , 59.64241518, 59.84833355, 60.05425192, 60.2601703 ,
#         60.46608867, 60.67200705, 60.87792542, 61.0838438 , 61.28976217,
#         61.49568054, 61.70159892, 61.90751729, 62.11343567, 62.31935404,
#         62.52527241, 62.73119079, 62.93710916, 63.14302754, 63.34894591,
#         63.55486429, 63.76078266, 63.96670103, 64.17261941, 64.37853778,
#         64.58445616, 64.79037453, 64.9962929 , 65.20221128, 65.40812965,
#         65.61404803, 65.8199664 , 66.02588478, 66.23180315, 66.43772152,
#         66.6436399 , 66.84955827, 67.05547665, 67.26139502, 67.46731339,
#         67.67323177, 67.87915014, 68.08506852, 68.29098689, 68.49690526,
#         68.70282364, 68.90874201, 69.11466039, 69.32057876, 69.52649714,
#         69.73241551, 69.93833388, 70.14425226, 70.35017063, 70.55608901,
#         70.76200738, 70.96792575, 71.17384413, 71.3797625 , 71.58568088,
#         71.79159925, 71.99751763, 72.203436  , 72.40935437, 72.61527275,
#         72.82119112, 73.0271095 , 73.23302787, 73.43894624, 73.64486462,
#         73.85078299, 74.05670137, 74.26261974, 74.46853812, 74.67445649,
#         74.88037486, 75.08629324, 75.29221161, 75.49812999, 75.70404836,
#         75.90996673, 76.11588511, 76.32180348, 76.52772186, 76.73364023,
#         76.9395586 , 77.14547698, 77.35139535, 77.55731373, 77.7632321 ,
#         77.96915048, 78.17506885, 78.38098722, 78.5869056 , 78.79282397,
#         78.99874235]),
#  <BarContainer object of 100 artists>)

# %%
MHcount, MHdevision = np.histogram(MH,bins=100)
NMHcount, NMHdevision = np.histogram(NMH,bins=100)
KL_divergence(MHcount,NMHcount)
# Out:
# /tmp/ipykernel_1047/2900689964.py:3: RuntimeWarning: divide by zero encountered in true_divide
#   np.where(np.logical_and(p!=0,q!=0), p* np.log(p/q), 0 )
# /tmp/ipykernel_1047/2900689964.py:3: RuntimeWarning: invalid value encountered in true_divide
#   np.where(np.logical_and(p!=0,q!=0), p* np.log(p/q), 0 )
# /tmp/ipykernel_1047/2900689964.py:3: RuntimeWarning: divide by zero encountered in log
#   np.where(np.logical_and(p!=0,q!=0), p* np.log(p/q), 0 )
# /tmp/ipykernel_1047/2900689964.py:3: RuntimeWarning: invalid value encountered in multiply
#   np.where(np.logical_and(p!=0,q!=0), p* np.log(p/q), 0 )
# 84.31277169671142

# %%
PLT.plot(MHcount)
PLT.plot(NMHcount,c='red')

# %% [markdown]
# ### <font color="Brown">Jenson Shanon(KL)</font>
